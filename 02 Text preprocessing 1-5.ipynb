# %%
# pip install numpy
import numpy as np
# pip install pandas
import pandas as pd
# dplython
import pandas as pd
from dplython import (DplyFrame, X, diamonds, select, sift,
  sample_n, sample_frac, head, arrange, mutate, group_by,
  summarize, DelayFunction)

# %%
df_ytb1 = pd.read_csv("D:/대학원/논문/커뮤니케이션학과/유튜브.csv", encoding = "utf-8")
df_ytb1 = DplyFrame(df_ytb1)
print(df_ytb1.index)
print(df_ytb1)
# Out:
# RangeIndex(start=0, stop=20819, step=1)
#                글쓴이_ytb                                             제목_ytb  \
# 0             Gverts15  New COVID-19 study Confirms: "Beating up Asian...
# 1       KhalidgamerBoy  New COVID-19 study Confirms: "Beating up Asian...
# 2              kkossee  New COVID-19 study Confirms: "Beating up Asian...
# 3               Capher  New COVID-19 study Confirms: "Beating up Asian...
# 4               Capher  New COVID-19 study Confirms: "Beating up Asian...
# ...                ...                                                ...
# 20814       KrishnaRao  US President Biden addresses ‘vicious’ hate cr...
# 20815       VincentLui  US President Biden addresses ‘vicious’ hate cr...
# 20816       surendralo  US President Biden addresses ‘vicious’ hate cr...
# 20817  HatooTranslator  US President Biden addresses ‘vicious’ hate cr...
# 20818      JumpierBook  US President Biden addresses ‘vicious’ hate cr...
#
#                                                   댓글_ytb  날짜_ytb  line_number
# 0      Dear Ryan,\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n...   1시간 전            1
# 1      Where is he <U+0001F62D><U+0001F62D><U+0001F62...   3시간 전            2
# 2                               Dear Ryan CAN YOU UPLOAD   3시간 전            3
# 3                          Dear Ryan, can you come back?  10시간 전            4
# 4      Ryan didn't quit yet, according to fans, he mi...  10시간 전            5
# ...                                                  ...     ...          ...
# 20814  What's shocking is some of these people attack...   2개월 전         2216
# 20815  Americans: The people who attacked the Chinese...   2개월 전         2217
# 20816  I’m wondering that why so many Americans are  ...   2개월 전         2218
# 20817  You know i always afraid to go to america. Day...   2개월 전         2219
# 20818  This has to stop. We don't stop this, then the...   2개월 전         2220
#
# [20819 rows x 5 columns]

# %%
from nltk import word_tokenize
from nltk import WordPunctTokenizer
from tensorflow.keras.preprocessing.text import text_to_word_sequence
# Out:
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\tensor_shape_pb2.py:18: DeprecationWarning: Call to deprecated create function FileDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   DESCRIPTOR = _descriptor.FileDescriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\tensor_shape_pb2.py:36: DeprecationWarning: Call to deprecated create function FieldDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _descriptor.FieldDescriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\tensor_shape_pb2.py:29: DeprecationWarning: Call to deprecated create function Descriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _TENSORSHAPEPROTO_DIM = _descriptor.Descriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\types_pb2.py:19: DeprecationWarning: Call to deprecated create function FileDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   DESCRIPTOR = _descriptor.FileDescriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\types_pb2.py:33: DeprecationWarning: Call to deprecated create function EnumValueDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _descriptor.EnumValueDescriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\types_pb2.py:27: DeprecationWarning: Call to deprecated create function EnumDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _DATATYPE = _descriptor.EnumDescriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\types_pb2.py:287: DeprecationWarning: Call to deprecated create function FieldDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _descriptor.FieldDescriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\types_pb2.py:280: DeprecationWarning: Call to deprecated create function Descriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _SERIALIZEDDTYPE = _descriptor.Descriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\resource_handle_pb2.py:20: DeprecationWarning: Call to deprecated create function FileDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   DESCRIPTOR = _descriptor.FileDescriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\resource_handle_pb2.py:39: DeprecationWarning: Call to deprecated create function FieldDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _descriptor.FieldDescriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\resource_handle_pb2.py:32: DeprecationWarning: Call to deprecated create function Descriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _RESOURCEHANDLEPROTO_DTYPEANDSHAPE = _descriptor.Descriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\tensor_pb2.py:21: DeprecationWarning: Call to deprecated create function FileDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   DESCRIPTOR = _descriptor.FileDescriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\tensor_pb2.py:40: DeprecationWarning: Call to deprecated create function FieldDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _descriptor.FieldDescriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\tensor_pb2.py:33: DeprecationWarning: Call to deprecated create function Descriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _TENSORPROTO = _descriptor.Descriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\attr_value_pb2.py:21: DeprecationWarning: Call to deprecated create function FileDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   DESCRIPTOR = _descriptor.FileDescriptor(
# C:\Users\hanmi\Anaconda3\lib\site-packages\tensorflow\core\framework\attr_value_pb2.py:40: DeprecationWarning: Call to deprecated create function FieldDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _descriptor.FieldDescriptor(
# C:\Users\hanmi\Anaconda3\lib\enum.py:384: ResourceWarning: unclosed file <_io.TextIOWrapper name='D:/대학원/논문/커뮤니케이션학과/reply_paste.txt' mode='r' encoding='cp949'>
#   return cls.__new__(cls, value)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
댓글_ytb = df_ytb1 >> select(X.댓글_ytb)
댓글_ytb
# Out:
#                                                   댓글_ytb
# 0      Dear Ryan,\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n...
# 1      Where is he <U+0001F62D><U+0001F62D><U+0001F62...
# 2                               Dear Ryan CAN YOU UPLOAD
# 3                          Dear Ryan, can you come back?
# 4      Ryan didn't quit yet, according to fans, he mi...
# ...                                                  ...
# 20814  What's shocking is some of these people attack...
# 20815  Americans: The people who attacked the Chinese...
# 20816  I’m wondering that why so many Americans are  ...
# 20817  You know i always afraid to go to america. Day...
# 20818  This has to stop. We don't stop this, then the...
#
# [20819 rows x 1 columns]

# %%
# 토큰화
# word_tokenize
df_ytb1["token_ytb"] = df_ytb1.apply(lambda row: word_tokenize(row['댓글_ytb']), axis=1)
df_ytb1["token_ytb"]
# Out:
# 0                             [Dear, Ryan, ,, Plz, upload]
# 1        [Where, is, he, <, U+0001F62D, >, <, U+0001F62...
# 2                           [Dear, Ryan, CAN, YOU, UPLOAD]
# 3                 [Dear, Ryan, ,, can, you, come, back, ?]
# 4        [Ryan, did, n't, quit, yet, ,, according, to, ...
#                                ...
# 20814    [What, 's, shocking, is, some, of, these, peop...
# 20815    [Americans, :, The, people, who, attacked, the...
# 20816    [I, ’, m, wondering, that, why, so, many, Amer...
# 20817    [You, know, i, always, afraid, to, go, to, ame...
# 20818    [This, has, to, stop, ., We, do, n't, stop, th...
# Name: token_ytb, Length: 20819, dtype: object

# %%
# wordPunctTokenizer
df_ytb1.apply(lambda row: WordPunctTokenizer().tokenize(row['댓글_ytb']), axis=1)
# Out:
# 0                             [Dear, Ryan, ,, Plz, upload]
# 1        [Where, is, he, <, U, +, 0001F62D, ><, U, +, 0...
# 2                           [Dear, Ryan, CAN, YOU, UPLOAD]
# 3                 [Dear, Ryan, ,, can, you, come, back, ?]
# 4        [Ryan, didn, ', t, quit, yet, ,, according, to...
#                                ...
# 20814    [What, ', s, shocking, is, some, of, these, pe...
# 20815    [Americans, :, The, people, who, attacked, the...
# 20816    [I, ’, m, wondering, that, why, so, many, Amer...
# 20817    [You, know, i, always, afraid, to, go, to, ame...
# 20818    [This, has, to, stop, ., We, don, ', t, stop, ...
# Length: 20819, dtype: object

# %%
# 케라스의 text_to_word_sequence는 기본적으로 모든 알파벳을 소문자로 바꾸면서 마침표나 컴마, 느낌표 등의 구두점을 제거
df_ytb1.apply(lambda row: text_to_word_sequence(row['댓글_ytb']), axis=1)
# Out:
# 0        [dear, ryan, \r, \r, \r, \r, \r, \r, \r, \r, \...
# 1        [where, is, he, u, 0001f62d, u, 0001f62d, u, 0...
# 2                           [dear, ryan, can, you, upload]
# 3                       [dear, ryan, can, you, come, back]
# 4        [ryan, didn't, quit, yet, according, to, fans,...
#                                ...
# 20814    [what's, shocking, is, some, of, these, people...
# 20815    [americans, the, people, who, attacked, the, c...
# 20816    [i’m, wondering, that, why, so, many, american...
# 20817    [you, know, i, always, afraid, to, go, to, ame...
# 20818    [this, has, to, stop, we, don't, stop, this, t...
# Length: 20819, dtype: object

# %%
# Penn Treebank Tokenization
from nltk import TreebankWordTokenizer

# %%
TreebankWordTokenizer = TreebankWordTokenizer()
df_ytb1.apply(lambda row: TreebankWordTokenizer.tokenize(row['댓글_ytb']), axis=1)
# Out:
# 0                             [Dear, Ryan, ,, Plz, upload]
# 1        [Where, is, he, <, U+0001F62D, >, <, U+0001F62...
# 2                           [Dear, Ryan, CAN, YOU, UPLOAD]
# 3                 [Dear, Ryan, ,, can, you, come, back, ?]
# 4        [Ryan, did, n't, quit, yet, ,, according, to, ...
#                                ...
# 20814    [What, 's, shocking, is, some, of, these, peop...
# 20815    [Americans, :, The, people, who, attacked, the...
# 20816    [I’m, wondering, that, why, so, many, American...
# 20817    [You, know, i, always, afraid, to, go, to, ame...
# 20818    [This, has, to, stop., We, do, n't, stop, this...
# Length: 20819, dtype: object

# %%
# 문장 토큰화(Sentence Tokenization)
from nltk.tokenize import sent_tokenize

# %%
df_ytb1_댓글_doc = pd.read_csv("D:/대학원/논문/커뮤니케이션학과/df_ytb1_댓글_doc.csv", encoding = "utf-8")
df_ytb1_댓글_doc = DplyFrame(df_ytb1_댓글_doc)
df_ytb1_댓글_doc
# Out:
#    Unnamed: 0                                             댓글_doc
# 0           1   Dear Ryan,\r\r\n\r\r\n\r\r\n\r\r\n\r\r\n\r\r\...

# %%
df_ytb1_댓글_doc.apply(lambda row: sent_tokenize(row['댓글_doc']), axis=1)
# Out:
# 0    [ Dear Ryan,\r\r\n\r\r\n\r\r\n\r\r\n\r\r\n\r\r...
# dtype: object

# %%
# 문장 토큰화(Sentence Tokenization) - 한국어
import kss

text = '딥 러닝 자연어 처리가 재미있기는 합니다. 그런데 문제는 영어보다 한국어로 할 때 너무 어렵습니다. 이제 해보면 알걸요?'
print('한국어 문장 토큰화 :',kss.split_sentences(text))
# Out:
# [Kss]: Because there's no supported C++ morpheme analyzer, Kss will take pecab as a backend. :D
# For your information, Kss also supports mecab backend.
# We recommend you to install mecab or konlpy.tag.Mecab for faster execution of Kss.
# Please refer to following web sites for details:
# - mecab: https://cleancode-ws.tistory.com/97
# - konlpy.tag.Mecab: https://uwgdqo.tistory.com/363
# 한국어 문장 토큰화 : ['딥 러닝 자연어 처리가 재미있기는 합니다.', '그런데 문제는 영어보다 한국어로 할 때 너무 어렵습니다.', '이제 해보면 알걸요?']

# %%
# 품사 태깅(Part-of-speech tagging)
# NLTK와 KoNLPy를 이용한 영어, 한국어 토큰화 실습
from nltk import word_tokenize
from nltk import pos_tag
댓글_ytb_tag = df_ytb1.apply(lambda row: pos_tag(word_tokenize(row['댓글_ytb'])), axis=1)

# %%
댓글_ytb_tag.to_csv("D:/대학원/논문/커뮤니케이션학과/댓글_ytb_tag.csv", index = False)

# %%
from konlpy.tag import Okt
from konlpy.tag import Kkma

okt = Okt()
kkma = Kkma()

print('OKT 형태소 분석 :',okt.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('OKT 품사 태깅 :',okt.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('OKT 명사 추출 :',okt.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# OKT 형태소 분석 : ['열심히', '코딩', '한', '당신', ',', '연휴', '에는', '여행', '을', '가봐요']
# OKT 품사 태깅 : [('열심히', 'Adverb'), ('코딩', 'Noun'), ('한', 'Josa'), ('당신', 'Noun'), (',', 'Punctuation'), ('연휴', 'Noun'), ('에는', 'Josa'), ('여행', 'Noun'), ('을', 'Josa'), ('가봐요', 'Verb')]
# OKT 명사 추출 : ['코딩', '당신', '연휴', '여행']

# %%
# 표제어 추출(Lemmatization)
댓글_ytb_tag_df = pd.read_csv("D:/대학원/논문/커뮤니케이션학과/댓글_ytb_tag_df.csv", encoding = "utf-8")
댓글_ytb_tag_df
# Out:
#         Unnamed: 0     id                                              reply  \
# 0                1      1                               Dear Ryan Plz upload
# 1                2      1                               Dear Ryan Plz upload
# 2                3      1                               Dear Ryan Plz upload
# 3                4      1                               Dear Ryan Plz upload
# 4                5      2                                              Where
# ...            ...    ...                                                ...
# 333151      333152  20819  This has stop stop this then the whole world w...
# 333152      333153  20819  This has stop stop this then the whole world w...
# 333153      333154  20819  This has stop stop this then the whole world w...
# 333154      333155  20819  This has stop stop this then the whole world w...
# 333155      333156  20819  This has stop stop this then the whole world w...
#
#           token  tag
# 0          Dear  NNP
# 1          Ryan  NNP
# 2           Plz  NNP
# 3        upload   NN
# 4         Where  WRB
# ...         ...  ...
# 333151   filled  VBN
# 333152     with   IN
# 333153  nothing   NN
# 333154   except   IN
# 333155    ocean   NN
#
# [333156 rows x 5 columns]

# %%
from nltk import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
댓글_ytb_tag_df.loc[:, ["token"]].apply(lambda row: lemmatizer.lemmatize(row['token']), axis=1)
# Out:
# 0            Dear
# 1            Ryan
# 2             Plz
# 3          upload
# 4           Where
#            ...
# 333151     filled
# 333152       with
# 333153    nothing
# 333154     except
# 333155      ocean
# Length: 333156, dtype: object

# %%
# 어간 추출(Stemming)
from nltk import PorterStemmer
from nltk import word_tokenize

# %%
stemmer = PorterStemmer()
댓글_ytb_tag_df.loc[:, ["token"]].apply(lambda row : stemmer.stem(row["token"]), axis = 1)
# Out:
# 0           dear
# 1           ryan
# 2            plz
# 3         upload
# 4          where
#            ...
# 333151      fill
# 333152      with
# 333153      noth
# 333154    except
# 333155     ocean
# Length: 333156, dtype: object

# %%
words = ['formalize', 'allowance', 'electricical']

[stemmer.stem(word) for word in words]
# Out:
# ['formal', 'allow', 'electric']

# %%
from nltk.stem import LancasterStemmer

# %%
porter_stemmer = PorterStemmer()
lancaster_stemmer = LancasterStemmer()

# %%
댓글_ytb_tag_df.loc[:, ["token"]].apply(lambda row : lancaster_stemmer.stem(row["token"]), axis = 1)
# Out:
# 0           dear
# 1           ryan
# 2            plz
# 3         upload
# 4           wher
#            ...
# 333151       fil
# 333152      with
# 333153      noth
# 333154    exceiv
# 333155        oc
# Length: 333156, dtype: object

# %%
# 불용어(Stopword)
from nltk.corpus import stopwords
from nltk import word_tokenize 
from konlpy.tag import Okt

# %%
stop_words = stopwords.words("english")
len(stop_words)
stop_words
stop_words.__class__ # class 확인
# Out:
# list

# %%
stop_words_set = set(stopwords.words('english')) # 집합, 중복되지 않는 원소(unique) 얻을 때

# %%
stop_words_set.__class__
list(stop_words_set).__class__ # set을 list로 변환
list(stop_words_set)
# Out:
# ['yours',
#  'is',
#  'same',
#  "doesn't",
#  "don't",
#  'ourselves',
#  'herself',
#  'has',
#  'from',
#  'between',
#  'until',
#  'their',
#  'does',
#  "mustn't",
#  'there',
#  'while',
#  'below',
#  'with',
#  'am',
#  "aren't",
#  'for',
#  'weren',
#  'should',
#  'when',
#  'very',
#  'its',
#  'on',
#  'shan',
#  'of',
#  'her',
#  'as',
#  'he',
#  'i',
#  'my',
#  'again',
#  'after',
#  'couldn',
#  "you'd",
#  'by',
#  'mightn',
#  'doesn',
#  'was',
#  'where',
#  'each',
#  'now',
#  'you',
#  'during',
#  "wouldn't",
#  'if',
#  'most',
#  'were',
#  'once',
#  'being',
#  'y',
#  'be',
#  'only',
#  'ma',
#  'ours',
#  'in',
#  'further',
#  'yourself',
#  'having',
#  "she's",
#  'hadn',
#  'then',
#  "won't",
#  "shouldn't",
#  'we',
#  'had',
#  'themselves',
#  'himself',
#  'hers',
#  'they',
#  'are',
#  'this',
#  'do',
#  "hadn't",
#  "you've",
#  'such',
#  'she',
#  'own',
#  'haven',
#  'all',
#  'what',
#  'ain',
#  'both',
#  'other',
#  'to',
#  'me',
#  'how',
#  "should've",
#  'than',
#  'it',
#  'at',
#  'itself',
#  'few',
#  "isn't",
#  'about',
#  'just',
#  'so',
#  'mustn',
#  'been',
#  'and',
#  'nor',
#  'his',
#  'who',
#  'no',
#  'm',
#  'the',
#  'through',
#  's',
#  'under',
#  'whom',
#  "weren't",
#  'because',
#  'did',
#  'd',
#  'above',
#  'your',
#  'which',
#  'have',
#  "shan't",
#  'but',
#  'yourselves',
#  "needn't",
#  'needn',
#  'hasn',
#  'an',
#  'down',
#  'theirs',
#  't',
#  'o',
#  'why',
#  'out',
#  'up',
#  "haven't",
#  'shouldn',
#  "it's",
#  "you're",
#  'will',
#  'can',
#  "mightn't",
#  'won',
#  'or',
#  'myself',
#  'before',
#  'that',
#  'him',
#  'those',
#  'wouldn',
#  're',
#  'them',
#  "you'll",
#  'll',
#  'here',
#  'a',
#  'aren',
#  "hasn't",
#  'not',
#  'isn',
#  'over',
#  've',
#  "didn't",
#  'didn',
#  'doing',
#  'off',
#  'into',
#  'too',
#  'these',
#  "that'll",
#  "couldn't",
#  'our',
#  'against',
#  'some',
#  "wasn't",
#  'any',
#  'wasn',
#  'more',
#  'don']

# %%
word_tokens = 댓글_ytb_tag_df.loc[:, ["token"]].apply(lambda row : word_tokenize(row["token"]), axis = 1)
word_tokens
# Out:
# 0            [Dear]
# 1            [Ryan]
# 2             [Plz]
# 3          [upload]
# 4           [Where]
#             ...
# 333151     [filled]
# 333152       [with]
# 333153    [nothing]
# 333154     [except]
# 333155      [ocean]
# Length: 333156, dtype: object

# %%
result = []
for word in word_tokens :
    if word not in stop_words :
        result.append(word)
result
# Out:
# [['Dear'],
#  ['Ryan'],
#  ['Plz'],
#  ['upload'],
#  ['Where'],
#  ['Dear'],
#  ['Ryan'],
#  ['CAN'],
#  ['YOU'],
#  ['UPLOAD'],
#  ['Dear'],
#  ['Ryan'],
#  ['can'],
#  ['you'],
#  ['come'],
#  ['back'],
#  ['Ryan'],
#  ['did'],
#  ['quit'],
#  ['yet'],
#  ['according'],
#  ['fans'],
#  ['might'],
#  ['taking'],
#  ['break'],
#  ['from'],
#  ['skits'],
#  ['because'],
#  ['COVID'],
#  ['and'],
#  ['ended'],
#  ['Great'],
#  ['job'],
#  ['spilling'],
#  ['knowledge'],
#  ['the'],
#  ['retards'],
#  ['who'],
#  ['don'],
#  ['know'],
#  ['better'],
#  ['miss'],
#  ['the'],
#  ['quality'],
#  ['content'],
#  ['When'],
#  ['are'],
#  ['you'],
#  ['going'],
#  ['upload'],
#  ['been'],
#  ['year'],
#  ['share'],
#  ['the'],
#  ['same'],
#  ['bday'],
#  ['you'],
#  ['jume'],
#  ['the'],
#  ['worst'],
#  ['thing'],
#  ['that'],
#  ['people'],
#  ['like'],
#  ['ray'],
#  ['actually'],
#  ['exists'],
#  ['This'],
#  ['video'],
#  ['still'],
#  ['relevant'],
#  ['year'],
#  ['later'],
#  ['laughing'],
#  ['hard'],
#  ['Goobye'],
#  ['ryan'],
#  ['miss'],
#  ['you'],
#  ['bro'],
#  ['loved'],
#  ['his'],
#  ['videos'],
#  ['but'],
#  ['covid'],
#  ['fucked'],
#  ['everything'],
#  ['been'],
#  ['year'],
#  ['waiting'],
#  ['for'],
#  ['next'],
#  ['video'],
#  ['beat'],
#  ['asians'],
#  ['Holasoygerman'],
#  ['its'],
#  ['been'],
#  ['year'],
#  ['missing'],
#  ['you'],
#  ['man'],
#  ['hope'],
#  ['you'],
#  ['upload'],
#  ['soon'],
#  ['you'],
#  ['always'],
#  ['put'],
#  ['smile'],
#  ['face'],
#  ['Take'],
#  ['much'],
#  ['time'],
#  ['you'],
#  ['need'],
#  ['Maybe'],
#  ['has'],
#  ['COVID'],
#  ['think'],
#  ['Ryan'],
#  ['needs'],
#  ['make'],
#  ['new'],
#  ['video'],
#  ['addressing'],
#  ['the'],
#  ['fact'],
#  ['that'],
#  ['has'],
#  ['switched'],
#  ['streaming'],
#  ['Twitch'],
#  ['now'],
#  ['not'],
#  ['lot'],
#  ['people'],
#  ['know'],
#  ['about'],
#  ['this'],
#  ['fact'],
#  ['and'],
#  ['lot'],
#  ['people'],
#  ['are'],
#  ['thinking'],
#  ['just'],
#  ['taking'],
#  ['long'],
#  ['ass'],
#  ['break'],
#  ['you'],
#  ['think'],
#  ['quit'],
#  ['actually'],
#  ['didnt'],
#  ['his'],
#  ['other'],
#  ['channel'],
#  ['HigaTv'],
#  ['still'],
#  ['active'],
#  ['where'],
#  ['uploads'],
#  ['daily'],
#  ['Were'],
#  ['you'],
#  ['the'],
#  ['movie'],
#  ['FINDING'],
#  ['OHANA'],
#  ['right'],
#  ['dude'],
#  ['you'],
#  ['were'],
#  ['the'],
#  ['first'],
#  ['channel'],
#  ['hit'],
#  ['MILL'],
#  ['Congrats'],
#  ['man'],
#  ['Pain'],
#  ['this'],
#  ['fun'],
#  ['thank'],
#  ['you'],
#  ['for'],
#  ['incredible'],
#  ['content'],
#  ['Dear'],
#  ['ryan'],
#  ['Please'],
#  ['come'],
#  ['back'],
#  ['COME'],
#  ['BACKKKKK'],
#  ['Dear'],
#  ['Ryan'],
#  ['Can'],
#  ['you'],
#  ['come'],
#  ['back'],
#  ['The'],
#  ['fact'],
#  ['that'],
#  ['this'],
#  ['really'],
#  ['true'],
#  ['come'],
#  ['back'],
#  ['man'],
#  ['left'],
#  ['when'],
#  ['needed'],
#  ['him'],
#  ['most'],
#  ['this'],
#  ['video'],
#  ['aged'],
#  ['really'],
#  ['well'],
#  ['and'],
#  ['when'],
#  ['the'],
#  ['world'],
#  ['needed'],
#  ['him'],
#  ['most'],
#  ['disappeared'],
#  ['views'],
#  ['too'],
#  ['low'],
#  ['not'],
#  ['gone'],
#  ['has'],
#  ['second'],
#  ['channel'],
#  ['for'],
#  ['like'],
#  ['ten'],
#  ['years'],
#  ['Higatv'],
#  ['Dear'],
#  ['Ryan'],
#  ['could'],
#  ['you'],
#  ['plis'],
#  ['start'],
#  ['uploading'],
#  ['videos'],
#  ['this'],
#  ['channel'],
#  ['Dear'],
#  ['Ryan'],
#  ['Don'],
#  ['speak'],
#  ['out'],
#  ['against'],
#  ['China'],
#  ['Ryan'],
#  ['you'],
#  ['are'],
#  ['childhood'],
#  ['and'],
#  ['you'],
#  ['used'],
#  ['idol'],
#  ['lmao'],
#  ['Love'],
#  ['you'],
#  ['When'],
#  ['are'],
#  ['you'],
#  ['going'],
#  ['upload'],
#  ['miss'],
#  ['this'],
#  ['guy'],
#  ['use'],
#  ['watch'],
#  ['this'],
#  ['guy'],
#  ['everyday'],
#  ['but'],
#  ['has'],
#  ['uploaded'],
#  ['such'],
#  ['long'],
#  ['time'],
#  ['luv'],
#  ['zisss'],
#  ['really'],
#  ['wish'],
#  ['nighhigha'],
#  ['would'],
#  ['start'],
#  ['posting'],
#  ['again'],
#  ['Hey'],
#  ['bro'],
#  ['come'],
#  ['back'],
#  ['you'],
#  ['guys'],
#  ['are'],
#  ['wondering'],
#  ['where'],
#  ['streams'],
#  ['twitch'],
#  ['Bro'],
#  ['you'],
#  ['were'],
#  ['whole'],
#  ['childhood'],
#  ['Please'],
#  ['come'],
#  ['back'],
#  ['brother'],
#  ['The'],
#  ['YouTube'],
#  ['world'],
#  ['really'],
#  ['need'],
#  ['your'],
#  ['creativity'],
#  ['back'],
#  ['Ryan'],
#  ['Everywhere'],
#  ['look'],
#  ['just'],
#  ['another'],
#  ['shitty'],
#  ['YouTube'],
#  ['short'],
#  ['copied'],
#  ['from'],
#  ['Tiktok'],
#  ['Comeback'],
#  ['man'],
#  ['Mate'],
#  ['remember'],
#  ['back'],
#  ['the'],
#  ['day'],
#  ['when'],
#  ['taught'],
#  ['become'],
#  ['real'],
#  ['gangster'],
#  ['emo'],
#  ['ninja'],
#  ['you'],
#  ['name'],
#  ['Just'],
#  ['year'],
#  ['ago'],
#  ['still'],
#  ['teaching'],
#  ['how'],
#  ['real'],
#  ['decent'],
#  ['human'],
#  ['beings'],
#  ['damn'],
#  ['year'],
#  ['man'],
#  ['thanks'],
#  ['for'],
#  ['everythign'],
#  ['came'],
#  ['back'],
#  ['when'],
#  ['the'],
#  ['world'],
#  ['needed'],
#  ['him'],
#  ['the'],
#  ['most'],
#  ['asian'],
#  ['mom'],
#  ['beat'],
#  ['when'],
#  ['was'],
#  ['little'],
#  ['and'],
#  ['have'],
#  ['got'],
#  ['the'],
#  ['virus'],
#  ['yet'],
#  ['Coincidence'],
#  ['still'],
#  ['has'],
#  ['uploaded'],
#  ['been'],
#  ['year'],
#  ['need'],
#  ['him'],
#  ['during'],
#  ['Covid'],
#  ['Pls'],
#  ['come'],
#  ['back'],
#  ['use'],
#  ['watch'],
#  ['him'],
#  ['with'],
#  ['dial'],
#  ['connection'],
#  ['Dear'],
#  ['Ryan'],
#  ['please'],
#  ['come'],
#  ['back'],
#  ['Fun'],
#  ['fact'],
#  ['still'],
#  ['uploads'],
#  ['frequently'],
#  ['HigaTv'],
#  ['Nothing'],
#  ['Pls'],
#  ['comeback'],
#  ['been'],
#  ['one'],
#  ['year'],
#  ['cant'],
#  ['believe'],
#  ['found'],
#  ['your'],
#  ['channel'],
#  ['again'],
#  ['glad'],
#  ['did'],
#  ['just'],
#  ['does'],
#  ['his'],
#  ['voice'],
#  ['sound'],
#  ['like'],
#  ['hes'],
#  ['the'],
#  ['verge'],
#  ['laughing'],
#  ['Ryan'],
#  ['stick'],
#  ['the'],
#  ['funny'],
#  ['original'],
#  ['videos'],
#  ['the'],
#  ['controversal'],
#  ['videos'],
#  ['are'],
#  ['not'],
#  ['really'],
#  ['interesting'],
#  ['like'],
#  ['watching'],
#  ['the'],
#  ['news'],
#  ['been'],
#  ['year'],
#  ['Ryan'],
#  ['been'],
#  ['over'],
#  ['year'],
#  ['since'],
#  ['this'],
#  ['upload'],
#  ['and'],
#  ['just'],
#  ['wanted'],
#  ['say'],
#  ['that'],
#  ['remember'],
#  ['friends'],
#  ['showing'],
#  ['your'],
#  ['account'],
#  ['year'],
#  ['and'],
#  ['watching'],
#  ['your'],
#  ['videos'],
#  ['after'],
#  ['that'],
#  ['and'],
#  ['thank'],
#  ['you'],
#  ['for'],
#  ['all'],
#  ['the'],
#  ['nostalgia'],
#  ['Current'],
#  ['uploads'],
#  ['ever'],
#  ['since'],
#  ['last'],
#  ['year'],
#  ['number'],
#  ['its'],
#  ['been'],
#  ['months'],
#  ['Ryan'],
#  ['uploaded'],
#  ['content'],
#  ['this'],
#  ['channel'],
#  ['PLS'],
#  ['UPLOAD'],
#  ['MORE'],
#  ['VIDS'],
#  ['ryan'],
#  ['come'],
#  ['back'],
#  ['its'],
#  ['been'],
#  ['year'],
#  ['that'],
#  ['vietnam'],
#  ['war'],
#  ['joke'],
#  ['Also'],
#  ['hope'],
#  ['you'],
#  ['will'],
#  ['back'],
#  ['Ryan'],
#  ['miss'],
#  ['Soory'],
#  ['Ryan'],
#  ['have'],
#  ['unsubcribe'],
#  ['guy'],
#  ['are'],
#  ['you'],
#  ['died'],
#  ['Come'],
#  ['back'],
#  ['Come'],
#  ['back'],
#  ['Come'],
#  ['back'],
#  ['turned'],
#  ['into'],
#  ['ceeday'],
#  ['Ryan'],
#  ['Sylvia'],
#  ['said'],
#  ['Dear'],
#  ['Ryan'],
#  ['can'],
#  ['you'],
#  ['challenge'],
#  ['sean'],
#  ['for'],
#  ['real'],
#  ['judo'],
#  ['match'],
#  ['off'],
#  ['where'],
#  ['are'],
#  ['higa'],
#  ['This'],
#  ['guy'],
#  ['too'],
#  ['smart'],
#  ['for'],
#  ['the'],
#  ['current'],
#  ['generation'],
#  ['YouTube'],
#  ['watchers'],
#  ['appreciate'],
#  ['NigaHiga'],
#  ['was'],
#  ['the'],
#  ['peak'],
#  ['one'],
#  ['time'],
#  ['and'],
#  ['glad'],
#  ['got'],
#  ['witness'],
#  ['miss'],
#  ['you'],
#  ['man'],
#  ['Not'],
#  ['saying'],
#  ['this'],
#  ['isn'],
#  ['wrong'],
#  ['yes'],
#  ['this'],
#  ['very'],
#  ['fucked'],
#  ['but'],
#  ['Back'],
#  ['asian'],
#  ['the'],
#  ['racism'],
#  ['others'],
#  ['still'],
#  ['off'],
#  ['the'],
#  ['charts'],
#  ['towards'],
#  ['blacks'],
#  ['mostly'],
#  ['see'],
#  ['Hate'],
#  ['for'],
#  ['hate'],
#  ['endless'],
#  ['cycle'],
#  ['that'],
#  ['only'],
#  ['love'],
#  ['can'],
#  ['beat'],
#  ['Racist'],
#  ['dude'],
#  ['back'],
#  ['your'],
#  ['country'],
#  ['Asian'],
#  ['Alright'],
#  ['back'],
#  ['New'],
#  ['York'],
#  ['Racist'],
#  ['dude'],
#  ['Yeah'],
#  ['that'],
#  ['right'],
#  ['Wait'],
#  ['New'],
#  ['York'],
#  ['America'],
#  ['right'],
#  ['Asian'],
#  ['Yup'],
#  ['definitely'],
#  ['Not'],
#  ['America'],
#  ['Cya'],
#  ['love'],
#  ['this'],
#  ['guy'],
#  ['Was'],
#  ['that'],
#  ['American'],
#  ['just'],
#  ['fighting'],
#  ['tree'],
#  ['Where'],
#  ['Kabeh'],
#  ['videomu'],
#  ['jan'],
#  ['niat'],
#  ['tur'],
#  ['apik'],
#  ['buanget'],
#  ['sangar'],
#  ['idolaku'],
#  ['Nek'],
#  ['iki'],
#  ['video'],
#  ['terakhirmu'],
#  ['aku'],
#  ['meh'],
#  ['muni'],
#  ['matursuwun'],
#  ['sanget'],
#  ['wes'],
#  ['ngancani'],
#  ['aku'],
#  ['galau'],
#  ['pas'],
#  ['kuliah'],
#  ['bar'],
#  ['bar'],
#  ['akhire'],
#  ['bar'],
#  ['ngasek'],
#  ['iso'],
#  ['rabi'],
#  ['harang'],
#  ['Salam'],
#  ['seko'],
#  ['wong'],
#  ['jowo'],
#  ['negoro'],
#  ['Indonesia'],
#  ['Kangen'],
#  ['videomu'],
#  ['nang'],
#  ['yutup'],
#  ['lur'],
#  ['think'],
#  ['hasn'],
#  ['uploaded'],
#  ['cuz'],
#  ['personally'],
#  ['got'],
#  ['beat'],
#  ['after'],
#  ['this'],
#  ['video'],
#  ['Miss'],
#  ['you'],
#  ['much'],
#  ['bro'],
#  ['Love'],
#  ['from'],
#  ['India'],
#  ['Still'],
#  ['relevant'],
#  ['Has'],
#  ['anyone'],
#  ['noticed'],
#  ['that'],
#  ['Ryan'],
#  ['has'],
#  ['uploaded'],
#  ['thing'],
#  ['since'],
#  ['this'],
#  ['video'],
#  ['YALL'],
#  ['KNOW'],
#  ['HAS'],
#  ['ANOTHER'],
#  ['CHANNEL'],
#  ['Nice'],
#  ['Nice'],
#  ['Its'],
#  ['always'],
#  ['the'],
#  ['best'],
#  ['and'],
#  ['the'],
#  ['most'],
#  ['youtubers'],
#  ['who'],
#  ['quit'],
#  ['Ryan'],
#  ['why'],
#  ['you'],
#  ['quit'],
#  ['love'],
#  ['your'],
#  ['vids'],
#  ['much'],
#  ['Where'],
#  ['this'],
#  ['guy'],
#  ['Your'],
#  ['honour'],
#  ['how'],
#  ['can'],
#  ['hate'],
#  ['crime'],
#  ['client'],
#  ['loved'],
#  ['doing'],
#  ['Fun'],
#  ['fact'],
#  ['Ryan'],
#  ['uploads'],
#  ['Higa'],
#  ['now'],
#  ['but'],
#  ['only'],
#  ['makes'],
#  ['gaming'],
#  ['videos'],
#  ['and'],
#  ['streams'],
#  ['Bring'],
#  ['back'],
#  ['skitzo'],
#  ['Ryan'],
#  ['you'],
#  ['good'],
#  ['You'],
#  ['alive'],
#  ['Finally'],
#  ['one'],
#  ['news'],
#  ['channel'],
#  ['not'],
#  ['covering'],
#  ['and'],
#  ['obsessing'],
#  ['over'],
#  ['the'],
#  ['BLM'],
#  ['stuff'],
#  ['Expert'],
#  ['Charles'],
#  ['Patrick'],
#  ['the'],
#  ['best'],
#  ['recommending'],
#  ['him'],
#  ['all'],
#  ['beginners'],
#  ['who'],
#  ['wants'],
#  ['recover'],
#  ['losses'],
#  ['like'],
#  ['did'],
#  ['Wait'],
#  ['this'],
#  ['channel'],
#  ['and'],
#  ['skitzo'],
#  ['news'],
#  ['also'],
#  ['channel'],
#  ['then'],
#  ['where'],
#  ['the'],
#  ['others'],
#  ['Who'],
#  ['watching'],
#  ['this'],
#  ['Rest'],
#  ['Peace'],
#  ['May'],
#  ['meet'],
#  ['again'],
#  ['Ryan'],
#  ['need'],
#  ['him'],
#  ['back'],
#  ['now'],
#  ['Yall'],
#  ['saying'],
#  ['quit'],
#  ['youtube'],
#  ['didnt'],
#  ['posts'],
#  ['every'],
#  ['days'],
#  ['his'],
#  ['second'],
#  ['channel'],
#  ['HigaTV'],
#  ['nigahiga'],
#  ['BREAKING'],
#  ['NEWS'],
#  ['China'],
#  ['Asian'],
#  ['country'],
#  ['took'],
#  ['two'],
#  ['years'],
#  ['japanese'],
#  ['high'],
#  ['school'],
#  ['speak'],
#  ['chinese'],
#  ['proceeds'],
#  ['say'],
#  ['hello'],
#  ['korean'],
#  ['Haha'],
#  ['Ray'],
#  ['racist'],
#  ['man'],
#  ['the'],
#  ['middle'],
#  ['east'],
#  ['asia'],
#  ['still'],
#  ['africa'],
#  ['ACHOO'],
#  ['lol'],
#  ['man'],
#  ['earned'],
#  ['sub'],
#  ['let'],
#  ['get'],
#  ['him'],
#  ['more'],
#  ['subs'],
#  ['than'],
#  ['KSI'],
#  ['Beast'],
#  ['nigga'],
#  ['higa'],
#  ['nigga'],
#  ['higa'],
#  ['nigga'],
#  ['higa'],
#  ['nigga'],
#  ['higa'],
#  ['nigga'],
#  ['higa'],
#  ['nigga'],
#  ['higa'],
#  ['nigga'],
#  ['higa'],
#  ['nigga'],
#  ['higa'],
#  ['nigga'],
#  ['higa'],
#  ['This'],
#  ['logical'],
#  ['retired'],
#  ['from'],
#  ['the'],
#  ['main'],
#  ['channel'],
#  ['believe'],
#  ['RPHC'],
#  ['has'],
#  ['also'],
#  ['disbanded'],
#  ['Idk'],
#  ['comeback'],
#  ['anytime'],
#  ['soon'],
#  ['but'],
#  ['uploads'],
#  ['lot'],
#  ['HigaTV'],
#  ['Mann'],
#  ['please'],
#  ['come'],
#  ['back'],
#  ['will'],
#  ['cry'],
#  ['you'],
#  ['upload'],
#  ['plz'],
#  ['haven'],
#  ['uploaded'],
#  ['year'],
#  ['this'],
#  ['the'],
#  ['last'],
#  ['time'],
#  ['would'],
#  ['like'],
#  ['thank'],
#  ['you'],
#  ['for'],
#  ['amazing'],
#  ['videos'],
#  ['and'],
#  ['for'],
#  ['making'],
#  ['childhood'],
#  ['wonderful'],
#  ['with'],
#  ['videos'],
#  ['miss'],
#  ['Has'],
#  ['left'],
#  ['ryan'],
#  ['where'],
#  ['are'],
#  ['you'],
#  ['hasn'],
#  ['dissapeared'],
#  ['just'],
#  ['post'],
#  ['higatv'],
#  ['now'],
#  ['Did'],
#  ['Ryan'],
#  ['retire'],
#  ['still'],
#  ['wondering'],
#  ['how'],
#  ['this'],
#  ['guys'],
#  ['channel'],
#  ['name'],
#  ['hasnt'],
#  ['got'],
#  ['cancelled'],
#  ['lmaooo'],
#  ['Ryan'],
#  ['CAN'],
#  ['YOU'],
#  ['PLEASE'],
#  ['THE'],
#  ['NEW'],
#  ['FACE'],
#  ['POGCHAMP'],
#  ['PLEASE'],
#  ['YOUR'],
#  ['ARE'],
#  ...]

# %%
stop_words_ko = pd.read_csv("D:/대학원/논문/주제모형/한글_불용어.csv", encoding = "utf-8")
stop_words_ko = list(stop_words_ko)
okt = Okt()
댓글_ytb_tag_df["reply"].__class__
댓글_ytb_tag_df.loc[:, ["reply"]].__class__
# Out:
# pandas.core.frame.DataFrame

# %%
댓글_ytb_unique = DplyFrame(댓글_ytb_tag_df["reply"].unique())

# %%
댓글_ytb_unique.columns = ["reply"]
댓글_ytb_unique
# Out:
#                                                    reply
# 0                                   Dear Ryan Plz upload
# 1                                                  Where
# 2                               Dear Ryan CAN YOU UPLOAD
# 3                            Dear Ryan can you come back
# 4      Ryan did quit yet according fans might taking ...
# ...                                                  ...
# 19335  What shocking some these people attacking Asia...
# 19336  Americans The people who attacked the Chinese ...
# 19337  wondering that why many Americans are quite si...
# 19338  You know always afraid america Day day the rea...
# 19339  This has stop stop this then the whole world w...
#
# [19340 rows x 1 columns]

# %%
댓글_ytb_unique = 댓글_ytb_unique.loc[:, ["reply"]].apply(lambda row : word_tokenize(row["reply"]), axis = 1)
댓글_ytb_unique
# Out:
# 0                                [Dear, Ryan, Plz, upload]
# 1                                                  [Where]
# 2                           [Dear, Ryan, CAN, YOU, UPLOAD]
# 3                       [Dear, Ryan, can, you, come, back]
# 4        [Ryan, did, quit, yet, according, fans, might,...
#                                ...
# 19335    [What, shocking, some, these, people, attackin...
# 19336    [Americans, The, people, who, attacked, the, C...
# 19337    [wondering, that, why, many, Americans, are, q...
# 19338    [You, know, always, afraid, america, Day, day,...
# 19339    [This, has, stop, stop, this, then, the, whole...
# Length: 19340, dtype: object

# %%
result = []
for word in 댓글_ytb_unique :
    if word not in stop_words_ko :
        result.append(word)
result
# Out:
# [['Dear', 'Ryan', 'Plz', 'upload'],
#  ['Where'],
#  ['Dear', 'Ryan', 'CAN', 'YOU', 'UPLOAD'],
#  ['Dear', 'Ryan', 'can', 'you', 'come', 'back'],
#  ['Ryan',
#   'did',
#   'quit',
#   'yet',
#   'according',
#   'fans',
#   'might',
#   'taking',
#   'break',
#   'from',
#   'skits',
#   'because',
#   'COVID'],
#  ['and', 'ended'],
#  ['Great',
#   'job',
#   'spilling',
#   'knowledge',
#   'the',
#   'retards',
#   'who',
#   'don',
#   'know',
#   'better'],
#  ['miss', 'the', 'quality', 'content'],
#  ['When', 'are', 'you', 'going', 'upload'],
#  ['been', 'year'],
#  ['share', 'the', 'same', 'bday', 'you', 'jume'],
#  ['the',
#   'worst',
#   'thing',
#   'that',
#   'people',
#   'like',
#   'ray',
#   'actually',
#   'exists'],
#  ['This', 'video', 'still', 'relevant', 'year', 'later', 'laughing', 'hard'],
#  ['Goobye', 'ryan'],
#  ['miss', 'you', 'bro'],
#  ['loved', 'his', 'videos', 'but', 'covid', 'fucked', 'everything'],
#  ['been', 'year', 'waiting', 'for', 'next', 'video'],
#  ['beat', 'asians'],
#  ['Holasoygerman'],
#  ['its',
#   'been',
#   'year',
#   'missing',
#   'you',
#   'man',
#   'hope',
#   'you',
#   'upload',
#   'soon',
#   'you',
#   'always',
#   'put',
#   'smile',
#   'face',
#   'Take',
#   'much',
#   'time',
#   'you',
#   'need'],
#  ['Maybe', 'has', 'COVID'],
#  ['think',
#   'Ryan',
#   'needs',
#   'make',
#   'new',
#   'video',
#   'addressing',
#   'the',
#   'fact',
#   'that',
#   'has',
#   'switched',
#   'streaming',
#   'Twitch',
#   'now',
#   'not',
#   'lot',
#   'people',
#   'know',
#   'about',
#   'this',
#   'fact',
#   'and',
#   'lot',
#   'people',
#   'are',
#   'thinking',
#   'just',
#   'taking',
#   'long',
#   'ass',
#   'break'],
#  ['you',
#   'think',
#   'quit',
#   'actually',
#   'didnt',
#   'his',
#   'other',
#   'channel',
#   'HigaTv',
#   'still',
#   'active',
#   'where',
#   'uploads',
#   'daily'],
#  ['Were', 'you', 'the', 'movie', 'FINDING', 'OHANA', 'right'],
#  ['dude',
#   'you',
#   'were',
#   'the',
#   'first',
#   'channel',
#   'hit',
#   'MILL',
#   'Congrats',
#   'man'],
#  ['Pain'],
#  ['this', 'fun', 'thank', 'you', 'for', 'incredible', 'content'],
#  ['Dear', 'ryan', 'Please', 'come', 'back'],
#  ['COME', 'BACKKKKK'],
#  ['Dear', 'Ryan', 'Can', 'you', 'come', 'back'],
#  ['The', 'fact', 'that', 'this', 'really', 'true'],
#  ['come', 'back', 'man'],
#  ['left', 'when', 'needed', 'him', 'most'],
#  ['this', 'video', 'aged', 'really', 'well'],
#  ['and', 'when', 'the', 'world', 'needed', 'him', 'most', 'disappeared'],
#  ['views', 'too', 'low'],
#  ['not',
#   'gone',
#   'has',
#   'second',
#   'channel',
#   'for',
#   'like',
#   'ten',
#   'years',
#   'Higatv'],
#  ['Dear',
#   'Ryan',
#   'could',
#   'you',
#   'plis',
#   'start',
#   'uploading',
#   'videos',
#   'this',
#   'channel'],
#  ['Dear', 'Ryan', 'Don', 'speak', 'out', 'against', 'China'],
#  ['Ryan',
#   'you',
#   'are',
#   'childhood',
#   'and',
#   'you',
#   'used',
#   'idol',
#   'lmao',
#   'Love',
#   'you'],
#  ['miss',
#   'this',
#   'guy',
#   'use',
#   'watch',
#   'this',
#   'guy',
#   'everyday',
#   'but',
#   'has',
#   'uploaded',
#   'such',
#   'long',
#   'time'],
#  ['luv',
#   'zisss',
#   'really',
#   'wish',
#   'nighhigha',
#   'would',
#   'start',
#   'posting',
#   'again'],
#  ['Hey', 'bro', 'come', 'back'],
#  ['you', 'guys', 'are', 'wondering', 'where', 'streams', 'twitch'],
#  ['Bro',
#   'you',
#   'were',
#   'whole',
#   'childhood',
#   'Please',
#   'come',
#   'back',
#   'brother'],
#  ['The',
#   'YouTube',
#   'world',
#   'really',
#   'need',
#   'your',
#   'creativity',
#   'back',
#   'Ryan',
#   'Everywhere',
#   'look',
#   'just',
#   'another',
#   'shitty',
#   'YouTube',
#   'short',
#   'copied',
#   'from',
#   'Tiktok',
#   'Comeback',
#   'man'],
#  ['Mate',
#   'remember',
#   'back',
#   'the',
#   'day',
#   'when',
#   'taught',
#   'become',
#   'real',
#   'gangster',
#   'emo',
#   'ninja',
#   'you',
#   'name',
#   'Just',
#   'year',
#   'ago',
#   'still',
#   'teaching',
#   'how',
#   'real',
#   'decent',
#   'human',
#   'beings',
#   'damn'],
#  ['year', 'man', 'thanks', 'for', 'everythign'],
#  ['came', 'back', 'when', 'the', 'world', 'needed', 'him', 'the', 'most'],
#  ['asian',
#   'mom',
#   'beat',
#   'when',
#   'was',
#   'little',
#   'and',
#   'have',
#   'got',
#   'the',
#   'virus',
#   'yet',
#   'Coincidence'],
#  ['still',
#   'has',
#   'uploaded',
#   'been',
#   'year',
#   'need',
#   'him',
#   'during',
#   'Covid'],
#  ['Pls', 'come', 'back'],
#  ['use', 'watch', 'him', 'with', 'dial', 'connection'],
#  ['Dear', 'Ryan', 'please', 'come', 'back'],
#  ['Fun', 'fact', 'still', 'uploads', 'frequently', 'HigaTv'],
#  ['Nothing'],
#  ['Pls', 'comeback'],
#  ['been', 'one', 'year'],
#  ['cant', 'believe', 'found', 'your', 'channel', 'again', 'glad', 'did'],
#  ['just',
#   'does',
#   'his',
#   'voice',
#   'sound',
#   'like',
#   'hes',
#   'the',
#   'verge',
#   'laughing'],
#  ['Ryan',
#   'stick',
#   'the',
#   'funny',
#   'original',
#   'videos',
#   'the',
#   'controversal',
#   'videos',
#   'are',
#   'not',
#   'really',
#   'interesting',
#   'like',
#   'watching',
#   'the',
#   'news'],
#  ['Ryan',
#   'been',
#   'over',
#   'year',
#   'since',
#   'this',
#   'upload',
#   'and',
#   'just',
#   'wanted',
#   'say',
#   'that',
#   'remember',
#   'friends',
#   'showing',
#   'your',
#   'account',
#   'year',
#   'and',
#   'watching',
#   'your',
#   'videos',
#   'after',
#   'that',
#   'and',
#   'thank',
#   'you',
#   'for',
#   'all',
#   'the',
#   'nostalgia'],
#  ['Current', 'uploads', 'ever', 'since', 'last', 'year', 'number'],
#  ['its', 'been', 'months', 'Ryan', 'uploaded', 'content', 'this', 'channel'],
#  ['PLS', 'UPLOAD', 'MORE', 'VIDS'],
#  ['ryan', 'come', 'back', 'its', 'been', 'year'],
#  ['that',
#   'vietnam',
#   'war',
#   'joke',
#   'Also',
#   'hope',
#   'you',
#   'will',
#   'back',
#   'Ryan',
#   'miss'],
#  ['Soory', 'Ryan', 'have', 'unsubcribe'],
#  ['guy', 'are', 'you', 'died'],
#  ['Come', 'back'],
#  ['turned', 'into', 'ceeday'],
#  ['Ryan',
#   'Sylvia',
#   'said',
#   'Dear',
#   'Ryan',
#   'can',
#   'you',
#   'challenge',
#   'sean',
#   'for',
#   'real',
#   'judo',
#   'match',
#   'off'],
#  ['where', 'are', 'higa'],
#  ['This',
#   'guy',
#   'too',
#   'smart',
#   'for',
#   'the',
#   'current',
#   'generation',
#   'YouTube',
#   'watchers',
#   'appreciate',
#   'NigaHiga',
#   'was',
#   'the',
#   'peak',
#   'one',
#   'time',
#   'and',
#   'glad',
#   'got',
#   'witness'],
#  ['miss', 'you', 'man'],
#  ['Not',
#   'saying',
#   'this',
#   'isn',
#   'wrong',
#   'yes',
#   'this',
#   'very',
#   'fucked',
#   'but',
#   'Back',
#   'asian',
#   'the',
#   'racism',
#   'others',
#   'still',
#   'off',
#   'the',
#   'charts',
#   'towards',
#   'blacks',
#   'mostly',
#   'see',
#   'Hate',
#   'for',
#   'hate',
#   'endless',
#   'cycle',
#   'that',
#   'only',
#   'love',
#   'can',
#   'beat'],
#  ['Racist',
#   'dude',
#   'back',
#   'your',
#   'country',
#   'Asian',
#   'Alright',
#   'back',
#   'New',
#   'York',
#   'Racist',
#   'dude',
#   'Yeah',
#   'that',
#   'right',
#   'Wait',
#   'New',
#   'York',
#   'America',
#   'right',
#   'Asian',
#   'Yup',
#   'definitely',
#   'Not',
#   'America',
#   'Cya'],
#  ['love', 'this', 'guy'],
#  ['Was', 'that', 'American', 'just', 'fighting', 'tree'],
#  ['Kabeh',
#   'videomu',
#   'jan',
#   'niat',
#   'tur',
#   'apik',
#   'buanget',
#   'sangar',
#   'idolaku',
#   'Nek',
#   'iki',
#   'video',
#   'terakhirmu',
#   'aku',
#   'meh',
#   'muni',
#   'matursuwun',
#   'sanget',
#   'wes',
#   'ngancani',
#   'aku',
#   'galau',
#   'pas',
#   'kuliah',
#   'bar',
#   'bar',
#   'akhire',
#   'bar',
#   'ngasek',
#   'iso',
#   'rabi',
#   'harang',
#   'Salam',
#   'seko',
#   'wong',
#   'jowo',
#   'negoro',
#   'Indonesia',
#   'Kangen',
#   'videomu',
#   'nang',
#   'yutup',
#   'lur'],
#  ['think',
#   'hasn',
#   'uploaded',
#   'cuz',
#   'personally',
#   'got',
#   'beat',
#   'after',
#   'this',
#   'video'],
#  ['Miss', 'you', 'much', 'bro', 'Love', 'from', 'India'],
#  ['Still', 'relevant'],
#  ['Has',
#   'anyone',
#   'noticed',
#   'that',
#   'Ryan',
#   'has',
#   'uploaded',
#   'thing',
#   'since',
#   'this',
#   'video'],
#  ['YALL', 'KNOW', 'HAS', 'ANOTHER', 'CHANNEL'],
#  ['Nice'],
#  ['Its',
#   'always',
#   'the',
#   'best',
#   'and',
#   'the',
#   'most',
#   'youtubers',
#   'who',
#   'quit'],
#  ['Ryan', 'why', 'you', 'quit', 'love', 'your', 'vids', 'much'],
#  ['Where', 'this', 'guy'],
#  ['Your', 'honour', 'how', 'can', 'hate', 'crime', 'client', 'loved', 'doing'],
#  ['Fun',
#   'fact',
#   'Ryan',
#   'uploads',
#   'Higa',
#   'now',
#   'but',
#   'only',
#   'makes',
#   'gaming',
#   'videos',
#   'and',
#   'streams'],
#  ['Bring', 'back', 'skitzo'],
#  ['Ryan', 'you', 'good', 'You', 'alive'],
#  ['Finally',
#   'one',
#   'news',
#   'channel',
#   'not',
#   'covering',
#   'and',
#   'obsessing',
#   'over',
#   'the',
#   'BLM',
#   'stuff'],
#  ['Expert',
#   'Charles',
#   'Patrick',
#   'the',
#   'best',
#   'recommending',
#   'him',
#   'all',
#   'beginners',
#   'who',
#   'wants',
#   'recover',
#   'losses',
#   'like',
#   'did'],
#  ['Wait',
#   'this',
#   'channel',
#   'and',
#   'skitzo',
#   'news',
#   'also',
#   'channel',
#   'then',
#   'where',
#   'the',
#   'others'],
#  ['Who', 'watching', 'this'],
#  ['Rest', 'Peace'],
#  ['May', 'meet', 'again', 'Ryan'],
#  ['need', 'him', 'back', 'now'],
#  ['Yall',
#   'saying',
#   'quit',
#   'youtube',
#   'didnt',
#   'posts',
#   'every',
#   'days',
#   'his',
#   'second',
#   'channel',
#   'HigaTV'],
#  ['nigahiga'],
#  ['BREAKING', 'NEWS', 'China', 'Asian', 'country'],
#  ['took',
#   'two',
#   'years',
#   'japanese',
#   'high',
#   'school',
#   'speak',
#   'chinese',
#   'proceeds',
#   'say',
#   'hello',
#   'korean'],
#  ['Haha', 'Ray', 'racist', 'man'],
#  ['the', 'middle', 'east', 'asia', 'still', 'africa'],
#  ['ACHOO', 'lol'],
#  ['man',
#   'earned',
#   'sub',
#   'let',
#   'get',
#   'him',
#   'more',
#   'subs',
#   'than',
#   'KSI',
#   'Beast'],
#  ['nigga',
#   'higa',
#   'nigga',
#   'higa',
#   'nigga',
#   'higa',
#   'nigga',
#   'higa',
#   'nigga',
#   'higa',
#   'nigga',
#   'higa',
#   'nigga',
#   'higa'],
#  ['nigga', 'higa'],
#  ['This', 'logical'],
#  ['retired',
#   'from',
#   'the',
#   'main',
#   'channel',
#   'believe',
#   'RPHC',
#   'has',
#   'also',
#   'disbanded',
#   'Idk',
#   'comeback',
#   'anytime',
#   'soon',
#   'but',
#   'uploads',
#   'lot',
#   'HigaTV'],
#  ['Mann', 'please', 'come', 'back'],
#  ['will', 'cry', 'you', 'upload', 'plz'],
#  ['haven',
#   'uploaded',
#   'year',
#   'this',
#   'the',
#   'last',
#   'time',
#   'would',
#   'like',
#   'thank',
#   'you',
#   'for',
#   'amazing',
#   'videos',
#   'and',
#   'for',
#   'making',
#   'childhood',
#   'wonderful',
#   'with',
#   'videos'],
#  ['miss'],
#  ['Has', 'left'],
#  ['ryan', 'where', 'are', 'you'],
#  ['hasn', 'dissapeared', 'just', 'post', 'higatv', 'now'],
#  ['Did', 'Ryan', 'retire'],
#  ['still',
#   'wondering',
#   'how',
#   'this',
#   'guys',
#   'channel',
#   'name',
#   'hasnt',
#   'got',
#   'cancelled',
#   'lmaooo'],
#  ['Ryan',
#   'CAN',
#   'YOU',
#   'PLEASE',
#   'THE',
#   'NEW',
#   'FACE',
#   'POGCHAMP',
#   'PLEASE',
#   'YOUR',
#   'ARE',
#   'THE',
#   'PERFECT',
#   'ONE',
#   'AND',
#   'THE',
#   'CHOSEN',
#   'ONE'],
#  ['One',
#   'year',
#   'one',
#   'month',
#   'one',
#   'day',
#   'rip',
#   'fav',
#   'youtuber',
#   'never',
#   'posting',
#   'again'],
#  ['havent',
#   'uploaded',
#   'video',
#   'sence',
#   'one',
#   'year',
#   'did',
#   'you',
#   'get',
#   'covid'],
#  ['worried', 'has', 'uploaded', 'year', 'quiting'],
#  ['ryan'],
#  ['Does',
#   'his',
#   'awesome',
#   'combination',
#   'satire',
#   'and',
#   'puns',
#   'remind',
#   'you',
#   'Bit',
#   'Fry',
#   'and',
#   'Laurie'],
#  ['Dear', 'ryan', 'why', 'you', 'dont', 'upload', 'again'],
#  ['Come', 'back', 'Niga'],
#  ['Ryan', 'have', 'uploaded', 'year'],
#  ['when', 'the', 'next', 'video'],
#  ['This', 'man', 'bouta', 'commit', 'Bill', 'wurtz'],
#  ['Best', 'news', 'channel'],
#  ['miss', 'you'],
#  ['Where', 'are', 'you'],
#  ['Rayen',
#   'can',
#   'you',
#   'watch',
#   'video',
#   'from',
#   'jumpers',
#   'jump',
#   'and',
#   'tell',
#   'what',
#   'you',
#   'think',
#   'about'],
#  ['srsly', 'not', 'coming', 'back'],
#  ['Ryan',
#   'gone',
#   'the',
#   'time',
#   'where',
#   'need',
#   'him',
#   'the',
#   'most',
#   'need',
#   'Ryanhiga',
#   'comebacks',
#   'YouTube',
#   'Please',
#   'youtube'],
#  ['What', 'niga'],
#  ['Lol', 'cousin', 'name', 'raymond'],
#  ['anyone',
#   'else',
#   'notice',
#   'how',
#   'this',
#   'shit',
#   'actually',
#   'came',
#   'true',
#   'tho',
#   'and',
#   'became',
#   'the',
#   'next',
#   'dumb',
#   'shit',
#   'all',
#   'complain',
#   'about'],
#  ['WHYY', 'PLS', 'UPLOAD', 'MISS'],
#  ['Ryan', 'appreciate', 'you', 'bro', 'hope', 'you', 'doing', 'well'],
#  ['Ryan',
#   'another',
#   'movie',
#   'called',
#   'Finding',
#   'Ohana',
#   'you',
#   'should',
#   'check',
#   'out',
#   'has',
#   'really',
#   'good',
#   'reviews',
#   'That',
#   'also',
#   'the',
#   'reason',
#   'why',
#   'has',
#   'uploaded'],
#  ['Next', 'video'],
#  ['miss', 'Ryan', 'much', 'there', 'purpose', 'life', 'anymore'],
#  ['Damn', 'broo', 'died'],
#  ['are',
#   'still',
#   'waiting',
#   'for',
#   'your',
#   'next',
#   'upload',
#   'here',
#   'take',
#   'your',
#   'time'],
#  ['uploading', 'his', 'channel', 'Higatv'],
#  ['Where', 'the', 'are', 'you'],
#  ['When', 'will', 'the', 'skits', 'appear', 'again'],
#  ['Ryan', 'please', 'come', 'back'],
#  ['its', 'been', 'one', 'year', 'now'],
#  ['Who', 'waiting', 'for', 'another', 'video'],
#  ['waiting',
#   'for',
#   'new',
#   'video',
#   'and',
#   'there',
#   'nothing',
#   'stopping',
#   'except',
#   'have',
#   'cancer'],
#  ['year', 'now', 'plz', 'upload', 'video'],
#  ['NEED', 'NEW', 'VIDEO', 'FROM', 'YOU', 'PLZ', 'COME', 'BACK', 'GUY'],
#  ['Man', 'will', 'ever', 'return'],
#  ['Well',
#   'fellas',
#   'guess',
#   'over',
#   'Sad',
#   'see',
#   'the',
#   'old',
#   'dudes',
#   'die',
#   'out',
#   'but',
#   'atleast',
#   'made',
#   'beautiful',
#   'memories',
#   'the',
#   'way'],
#  ['Hmmm',
#   'dont',
#   'understand',
#   'why',
#   'not',
#   'posting',
#   'video',
#   'till',
#   'today',
#   'got',
#   'covid',
#   'Did',
#   'quit',
#   'youtube',
#   'Who',
#   'knows'],
#  ['But', 'when', 'the', 'world', 'needed', 'him', 'most', 'vanished'],
#  ['Dear', 'Ryan', 'can', 'you', 'make', 'youtube', 'channel', 'intro'],
#  ['MURICA'],
#  ['now',
#   'somebody',
#   'that',
#   'used',
#   'know',
#   'When',
#   'can',
#   'see',
#   'you',
#   'again'],
#  ['When', 'the', 'world', 'needed', 'him', 'most', 'disappeared'],
#  ['want',
#   'him',
#   'upload',
#   'again',
#   'like',
#   'used',
#   'used',
#   'make',
#   'day',
#   'those',
#   'videos',
#   'were',
#   'super',
#   'funny'],
#  ['WHERE', 'ARE'],
#  ['Dear',
#   'Ryan',
#   'Can',
#   'you',
#   'come',
#   'back',
#   'forgot',
#   'the',
#   'guy',
#   'who',
#   'commented',
#   'this',
#   'lets',
#   'start',
#   'comment',
#   'swarm',
#   'please',
#   'copy',
#   'this',
#   'and',
#   'paste',
#   'this',
#   'Ryan',
#   'streams'],
#  ['this', 'your', 'end', 'thank', 'you', 'for', 'you', 'entertainment'],
#  ['Goodbye', 'crazy', 'that', 'old', 'YouTube', 'gone'],
#  ['You', 'HAVE', 'UPLOAD', 'YEAR', 'WTH'],
#  ['You',
#   'even',
#   'need',
#   'study',
#   'show',
#   'that',
#   'beating',
#   'asians',
#   'does',
#   'not',
#   'get',
#   'rid',
#   'corona'],
#  ['miss', 'Ryan', 'Higa', 'videos'],
#  ['been', 'year', 'just', 'please', 'upload'],
#  ['Ummbare', 'you', 'ded', 'you', 'havent', 'pisted', 'for', 'year'],
#  ['Oof', 'year', 'ago'],
#  ['Thanks', 'for', 'everything', 'ryan', 'Hope', 'come', 'back', 'day'],
#  ['This', 'some', 'FUNNY', 'shit', 'Love'],
#  ['dear', 'ryan', 'can', 'come', 'back'],
#  ['Are', 'finding', 'ohana'],
#  ['little',
#   'sad',
#   'that',
#   'keep',
#   'checking',
#   'see',
#   'posted',
#   'even',
#   'though',
#   'know',
#   'that',
#   'going'],
#  ['Ryan',
#   'hasnt',
#   'uploaded',
#   'anything',
#   'because',
#   'this',
#   'one',
#   'video',
#   'was',
#   'enough',
#   'content',
#   'for',
#   'the',
#   'last',
#   'months'],
#  ['name', 'raymond'],
#  ['uploaooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooood',
#   'videeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeo'],
#  ['where',
#   'are',
#   'you',
#   'quarantine',
#   'driving',
#   'crazy',
#   'and',
#   'need',
#   'things',
#   'make',
#   'laugh'],
#  ['GUYS',
#   'JUST',
#   'SAYING',
#   'NOT',
#   'GONE',
#   'FROM',
#   'MAKING',
#   'CONTENT',
#   'STREAMS',
#   'HIS',
#   'TWITCH'],
#  ['Anyone', 'else', 'wondering', 'where', 'has', 'this', 'guy', 'gone'],
#  ['Ryan', 'better', 'safe', 'Plz', 'come', 'back'],
#  ['nigga', 'higga'],
#  ['Eee'],
#  ['What',
#   'legend',
#   'thia',
#   'was',
#   'the',
#   'first',
#   'man',
#   'get',
#   'mill',
#   'youtube'],
#  ['Welp', 'This', 'channel', 'seems', 'dead'],
#  ['remember', 'watching', 'this'],
#  ['True', 'true', 'Asian', 'Americans', 'came', 'from', 'the', 'not', 'china'],
#  ['hasent', 'posted', 'for', 'year'],
#  ['One',
#   'rape',
#   'accusation',
#   'against',
#   'his',
#   'team',
#   'and',
#   'gone',
#   'for',
#   'year',
#   'kek'],
#  ['dude', 'What', 'happened', 'you'],
#  ['ryan', 'need', 'you'],
#  ['Its',
#   'funny',
#   'how',
#   'asian',
#   'hate',
#   'spiked',
#   'now',
#   'and',
#   'not',
#   'the',
#   'beginning'],
#  ['dear', 'ryan', 'WHEN', 'GON', 'MAKE', 'NEW', 'VIDS'],
#  ['UPLOAD'],
#  ['fell', 'off', 'the', 'hood', 'watches', 'youngboy', 'videos'],
#  ['This', 'that', 'crazy', 'compilation'],
#  ['Where', 'did', 'Ryan', 'Are', 'you', 'alive'],
#  ['can',
#   'not',
#   'belive',
#   'that',
#   'putted',
#   'his',
#   'video',
#   'and',
#   'just',
#   'yeeted',
#   'out',
#   'the',
#   'for',
#   'long',
#   'time'],
#  ['Ray', 'Sisman', 'racist', 'man', 'Lol'],
#  ['The', 'Last', 'TEEHEE'],
#  ['Dear', 'Ryan', 'want', 'you', 'back'],
#  ['Dear', 'ryan', 'Dharin', 'your', 'brother'],
#  ['Ryan',
#   'Ryan',
#   'Ryan',
#   'please',
#   'come',
#   'back',
#   'from',
#   'the',
#   'store',
#   'after',
#   'you',
#   'purchase',
#   'milk',
#   'asap',
#   'waiting',
#   'for'],
#  ['hes', 'movie', 'called', 'ohana', 'Netflix'],
#  ['New', 'videos', 'please'],
#  ['Thanks', 'man', 'learned', 'much', 'from', 'this'],
#  ['For',
#   'those',
#   'who',
#   'know',
#   'streams',
#   'Twitch',
#   'not',
#   'his',
#   'links',
#   'for',
#   'whatever',
#   'reason',
#   'You',
#   'would',
#   'see',
#   'him',
#   'playing',
#   'Among',
#   'with',
#   'OTV',
#   'and',
#   'others',
#   'from',
#   'time',
#   'time',
#   'other',
#   'content',
#   'creators',
#   'videos',
#   'RHPC',
#   'disbanded',
#   'sometime',
#   'ago',
#   'watching',
#   'Jujutsu',
#   'Kaisen',
#   'just',
#   'living',
#   'life',
#   'This',
#   'was',
#   'copy',
#   'and',
#   'pasted'],
#  ['You', 'are', 'awesome', 'Major', 'respect', 'Great', 'video'],
#  ['Jenna',
#   'Marbels',
#   'and',
#   'Nigahiga',
#   'literally',
#   'two',
#   'favourite',
#   'youtubers',
#   'stopped',
#   'uploading',
#   'and',
#   'don',
#   'know',
#   'how',
#   'process'],
#  ['Upload', 'plz'],
#  ['come',
#   'here',
#   'often',
#   'with',
#   'the',
#   'hope',
#   'that',
#   'will',
#   'back',
#   'and',
#   'always',
#   'with',
#   'disappointment',
#   'come',
#   'back',
#   'plz'],
#  ['hope',
#   'this',
#   'isn',
#   'the',
#   'last',
#   'video',
#   'nigahiga',
#   'know',
#   'streams',
#   'and',
#   'uploads',
#   'highlights',
#   'HigaTV',
#   'but',
#   'Man',
#   'more',
#   'these',
#   'skits'],
#  ['Who', 'else', 'wants', 'him', 'back'],
#  ['this',
#   'the',
#   'last',
#   'upload',
#   'this',
#   'channel',
#   'and',
#   'its',
#   'been',
#   'more',
#   'than',
#   'one',
#   'year',
#   'since',
#   'the',
#   'release',
#   'this',
#   'video',
#   'wonder',
#   'what',
#   'happened'],
#  ['What', 'happened', 'you', 'man', 'miss', 'you'],
#  ['been', 'over', 'year'],
#  ['Bro',
#   'grew',
#   'you',
#   'haven',
#   'watched',
#   'video',
#   'yours',
#   'for',
#   'years',
#   'just',
#   'came',
#   'back',
#   'watch',
#   'all',
#   'your',
#   'videos',
#   'and',
#   'having',
#   'insane',
#   'nostalgic',
#   'feeling',
#   'much',
#   'love',
#   'you',
#   'are',
#   'legend'],
#  ['really',
#   'miss',
#   'Ryan',
#   'videos',
#   'will',
#   'always',
#   'one',
#   'most',
#   'favorite',
#   'YouTubers'],
#  ['Mans', 'entering', 'the', 'same', 'territory', 'FilthyFrank'],
#  ['The',
#   'people',
#   'who',
#   'disliked',
#   'are',
#   'all',
#   'probably',
#   'literally',
#   'exactly',
#   'like',
#   'the',
#   'white',
#   'character',
#   'They',
#   'that',
#   'much',
#   'fucking',
#   'joke',
#   'holy',
#   'shit'],
#  ['dead'],
#  ['And',
#   'remember',
#   'thinking',
#   'had',
#   'been',
#   'little',
#   'longer',
#   'then',
#   'his',
#   'YouTube',
#   'uploads',
#   'are',
#   'usually',
#   'spaced',
#   'apart'],
#  ['This',
#   'video',
#   'true',
#   'haters',
#   'are',
#   'gon',
#   'hate',
#   'matter',
#   'how',
#   'many',
#   'facts',
#   'you',
#   'throw',
#   'them'],
#  ['RYAN', 'WHAT', 'THE', 'BUTT', 'HAVE', 'YOU', 'NOT', 'BEEN', 'POSTING'],
#  ['where', 'are', 'you'],
#  ['CAN', 'GET', 'LIKES', 'STOP', 'ASIAN', 'HATE'],
#  ['higatv'],
#  ['Lol',
#   'Chinese',
#   'and',
#   'Micah',
#   'Korean',
#   'American',
#   'classmates',
#   'you',
#   'siblings'],
#  ['This',
#   'confusing',
#   'first',
#   'when',
#   'characters',
#   'look',
#   'the',
#   'same',
#   'was',
#   'like',
#   'yeah',
#   'yeah'],
#  ['Please', 'YouTube', 'isnt', 'the', 'same', 'without', 'the', 'OGs'],
#  ['will',
#   'miss',
#   'the',
#   'fun',
#   'times',
#   'had',
#   'from',
#   'watching',
#   'your',
#   'videos',
#   'Thanks',
#   'Ryan'],
#  ['its', 'been', 'year', 'why', 'not', 'uploading', 'are', 'you', 'okay'],
#  ['have',
#   'million',
#   'people',
#   'subbed',
#   'him',
#   'but',
#   'almost',
#   'half',
#   'them',
#   'aware',
#   'that',
#   'Nigahiga',
#   'offline'],
#  ['still', 'waiting', 'for', 'new', 'videos'],
#  ['Dear', 'ryan', 'you', 'watch', 'porn'],
#  ['dude', 'come', 'back', 'please', 'miss', 'you'],
#  ['Dear', 'Ryan', 'can', 'you', 'come', 'back', 'YouTube'],
#  ['miss', 'you', 'Ryan', 'You'],
#  ['why', 'gone'],
#  ['why', 'did', 'delete', 'videos'],
#  ['This', 'channel', 'feels', 'like', 'youtube', 'history'],
#  ['What', 'happened', 'him'],
#  ['Ryan',
#   'you',
#   'see',
#   'this',
#   'comment',
#   'please',
#   'upload',
#   'more',
#   'videos'],
#  ['offended', 'not', 'uploaded', 'video', 'pls', 'politically', 'correct'],
#  ['Why', 'video'],
#  ['RIP', 'the', 'Nigahiga', 'channel'],
#  ['Dear', 'Ryan', 'plzz', 'can', 'you', 'come', 'back'],
#  ['that', 'that', 'the', 'last', 'video', 'get', 'from', 'nigahiga', 'Sad'],
#  ['coming', 'check', 'Ryan', 'Only', 'see', 'that', 'has', 'uploaded', 'year'],
#  ['ryan', 'please', 'come', 'back'],
#  ['Didn', 'play', 'the', 'movie', 'finding', 'ohana'],
#  ['China',
#   'doin',
#   'some',
#   'Nazi',
#   'stuff',
#   'defend',
#   'TIAWAN',
#   'Philippines',
#   'free',
#   'Hong',
#   'Kong',
#   'boycott',
#   'Olympics',
#   'your',
#   'research'],
#  ['Why',
#   'did',
#   'only',
#   'show',
#   'hate',
#   'crimes',
#   'black',
#   'people',
#   'hating',
#   'Asians',
#   'and',
#   'then',
#   'went',
#   'blame',
#   'white',
#   'southerners'],
#  ['miss',
#   'you',
#   'and',
#   'here',
#   'when',
#   'you',
#   'upload',
#   'you',
#   'choose',
#   'upload',
#   'again',
#   'thank',
#   'you',
#   'for',
#   'always',
#   'bringing',
#   'laughter',
#   'and',
#   'happiness'],
#  ['Dear', 'Ryan', 'Can', 'you', 'please', 'comeback'],
#  ['Plz', 'make', 'video', 'plz'],
#  ['Ryan',
#   'damn',
#   'come',
#   'back',
#   'already',
#   'people',
#   'need',
#   'genuine',
#   'funny',
#   'content'],
#  ['Aged', 'well'],
#  ['Dear', 'ryan', 'please', 'post', 'new', 'video', 'miss', 'you'],
#  ['Miss', 'you', 'Ryan', 'Come', 'back', 'soon'],
#  ['Pls',
#   'come',
#   'back',
#   'you',
#   'are',
#   'the',
#   'only',
#   'thing',
#   'that',
#   'can',
#   'make',
#   'laugh'],
#  ['Dear', 'Ryan', 'can', 'you', 'marker', 'flip'],
#  ['Still',
#   'checking',
#   'out',
#   'from',
#   'time',
#   'time',
#   'ryan',
#   'and',
#   'his',
#   'squad',
#   'are',
#   'uploading',
#   'Miss',
#   'the',
#   'sensible',
#   'creators',
#   'and',
#   'youtubers',
#   'Missing',
#   'Ryan',
#   'squad',
#   'bad'],
#  ['This', 'vid', 'meaning', 'Common', 'sense'],
#  ['Ryan', 'please', 'come', 'back', 'Please'],
#  ['miss', 'you', 'come', 'back'],
#  ['Dear', 'ryan', 'please', 'come', 'back'],
#  ['Please', 'come', 'back', 'and', 'make', 'lesson', 'like', 'you', 'did'],
#  ['joe', 'mama'],
#  ['Where',
#   'need',
#   'you',
#   'youtube',
#   'boring',
#   'without',
#   'these',
#   'original',
#   'YouTubers'],
#  ['All', 'great', 'things', 'must', 'come', 'end'],
#  ['Aww', 'quit', 'youtube'],
#  ['Dear', 'Ryan', 'can', 'you', 'make', 'new', 'video'],
#  ['This', 'gold'],
#  ['been', 'year', 'since', 'this', 'was', 'posted'],
#  ['Dude', 'miss', 'you', 'please', 'make', 'vids', 'plesp'],
#  ['American', 'Asian', 'Asian', 'American'],
#  ['Dear', 'Ryan', 'Why', 'have', 'you', 'abandoned'],
#  ['Dear', 'ryan', 'can', 'you', 'come', 'back'],
#  ['miss', 'nigahiga', 'but', 'like', 'his', 'valorant'],
#  ['Dear', 'Ryan', 'can', 'you', 'stop', 'the', 'Israel', 'Palestine', 'war'],
#  ['plz', 'upload', 'sir'],
#  ['Hola',
#   'vivo',
#   'colombia',
#   'gustaria',
#   'enviarte',
#   'material',
#   'visual',
#   'que',
#   'esta',
#   'pasando',
#   'colombia'],
#  ['Bro', 'why', 'more', 'videos', 'Start', 'again', 'man', 'Start', 'New'],
#  ['This',
#   'findings',
#   'are',
#   'truly',
#   'shocking',
#   'Asian',
#   'American',
#   'myself',
#   'from',
#   'pakistan',
#   'but',
#   'aparently',
#   'Asian',
#   'according',
#   'legal',
#   'documents',
#   'beginning',
#   'suspect',
#   'maybe',
#   'just',
#   'maybe',
#   'might',
#   'not',
#   'terrorist'],
#  ['Post', 'already', 'bro'],
#  ['guessing', 'uploads', 'every', 'year'],
#  ['think', 'lost', 'his', 'password', 'for', 'this', 'channel'],
#  ['was',
#   'depressed',
#   'when',
#   'realised',
#   'that',
#   'since',
#   'has',
#   'posted',
#   'long',
#   'might',
#   'quitting',
#   'Rest',
#   'Peace',
#   'King'],
#  ['miss', 'this', 'channel'],
#  ['come', 'back', 'Ryan'],
#  ['goodbye', 'fren'],
#  ['Dear', 'Ryan', 'Please', 'come', 'back'],
#  ['Ahh', 'see', 'still', 'hasn', 'posted'],
#  ['are', 'you', 'dead'],
#  ['uploads', 'higatv'],
#  ['This',
#   'video',
#   'year',
#   'old',
#   'yet',
#   'this',
#   'his',
#   'newest',
#   'video',
#   'DISAPPEARED',
#   'FROM',
#   'YOUTUBE'],
#  ['Dear', 'Ryan', 'can', 'you', 'try', 'become', 'the', 'president'],
#  ['Ryan', 'come', 'back', 'miss', 'you'],
#  ['Randomly',
#   'remembered',
#   'how',
#   'ninja',
#   'and',
#   'came',
#   'back',
#   'looool',
#   'miss',
#   'you',
#   'come',
#   'back'],
#  ['Shhhiiittt'],
#  ['been',
#   'long',
#   'time',
#   'since',
#   'watched',
#   'this',
#   'man',
#   'and',
#   'after',
#   'all',
#   'this',
#   'time',
#   'still',
#   'has'],
#  ['really', 'miss', 'this', 'channel'],
#  ['would', 'crazy', 'when', 'uploads', 'again', 'love', 'his', 'videos'],
#  ['year', 'upload', 'gap'],
#  ['pls',
#   'ryan',
#   'can',
#   'come',
#   'back',
#   'would',
#   'rather',
#   'lose',
#   'year',
#   'lilfespan'],
#  ['typed',
#   'niga',
#   'google',
#   'and',
#   'popped',
#   'not',
#   'mad',
#   'Pretty',
#   'cool',
#   'channel'],
#  ['Was',
#   'the',
#   'gym',
#   'and',
#   'remembered',
#   'his',
#   'old',
#   'funny',
#   'videos',
#   'thought',
#   'see',
#   'how',
#   'now',
#   'sad',
#   'see',
#   'hasn',
#   'uploaded',
#   'over',
#   'year'],
#  ['dear',
#   'ryan',
#   'can',
#   'you',
#   'please',
#   'come',
#   'back',
#   'and',
#   'make',
#   'these',
#   'kind',
#   'videos',
#   'again'],
#  ['been',
#   'this',
#   'channel',
#   'for',
#   'long',
#   'The',
#   'Subscriber',
#   'count',
#   'decreasing',
#   'drastically',
#   'Atleast',
#   'make',
#   'collab',
#   'something',
#   'with',
#   'other',
#   'passionate',
#   'youtubers',
#   'Dont',
#   'waste',
#   'such',
#   'huge',
#   'fan',
#   'base',
#   'please'],
#  ['Where', 'are', 'you', 'Ryan'],
#  ['still', 'waiting', 'for', 'Ryan', 'new', 'video'],
#  ['Dear', 'Ryan', 'can', 'tell', 'the', 'truth', 'abou', 'bidden'],
#  ['you', 'get', 'this', 'sarcasm'],
#  ['pls', 'pls', 'pls', 'come', 'back'],
#  ['hay', 'hay', 'hay', 'goodbye'],
#  ['think', 'dead'],
#  ['miss', 'the', 'old', 'days', 'man'],
#  ['miss', 'his', 'humor'],
#  ['Dear', 'Ryan', 'can', 'you', 'come', 'back', 'pls'],
#  ['When', 'are', 'you', 'coming', 'back'],
#  ['Dear', 'Ryan', 'Come', 'back', 'please'],
#  ['miss', 'Ryan'],
#  ['Looks', 'Like', 'Someone', 'Forgot', 'Their', 'YouTube', 'PassWord'],
#  ['Sad', 'part', 'this', 'still', 'ongoing'],
#  ['The', 'korean', 'anyeonghaseyo', 'kills', 'everytimeee'],
#  ['Raymond', 'hmmm', 'here', 'and', 'you', 'watch', 'valkyrae', 'understand'],
#  ['where', 'ryan'],
#  ['really', 'thought', 'that', 'this', 'was', 'real', 'news', 'lol'],
#  ['RIP', 'nigahiga'],
#  ['make', 'video'],
#  ['Dear', 'god', 'been', 'whole', 'year'],
#  ['were', 'nigahiga'],
#  ['want', 'new', 'video'],
#  ['Dear',
#   'Ryan',
#   'can',
#   'you',
#   'please',
#   'come',
#   'back',
#   'not',
#   'appreciate',
#   'all',
#   'you',
#   'done',
#   'for'],
#  ['yes',
#   'the',
#   'ACHOO',
#   'The',
#   'leading',
#   'researcher',
#   'for',
#   'all',
#   'kinds',
#   'illnesses',
#   'and',
#   'disneezes',
#   'Thank',
#   'you',
#   'for',
#   'all',
#   'you',
#   'ACHOO',
#   'Bless',
#   'you',
#   'for',
#   'your',
#   'service'],
#  ['Come', 'back', 'please'],
#  ['Him', 'and', 'ceeday', 'both', 'disappeared', 'wtf', 'happend'],
#  ['mungkin',
#   'disini',
#   'ada',
#   'orang',
#   'indo',
#   'bisa',
#   'bantu',
#   'jelaskan',
#   'kenapa',
#   'dia',
#   'gak',
#   'upload',
#   'lagi',
#   'soalnya',
#   'skill',
#   'bahasa',
#   'Inggris',
#   'saya',
#   'ancur'],
#  ['Where',
#   'did',
#   'you',
#   'guy',
#   'miss',
#   'you',
#   'videos',
#   'grew',
#   'watching',
#   'you',
#   'since',
#   'was',
#   'like',
#   'now',
#   'man',
#   'you',
#   'got',
#   'come',
#   'back'],
#  ['Dear', 'Ryan', 'can', 'you', 'chair', 'flip'],
#  ['When', 'will', 'you', 'upload', 'your', 'next', 'video'],
#  ['filipino', 'also', 'asian'],
#  ['who', 'else', 'misses', 'nigahiga'],
#  ['need', 'Ryan', 'back'],
#  ['THIS', 'WAS'],
#  ['Why', 'they', 'quit', 'posting', 'videos'],
#  ['Dear', 'Ryan', 'miss', 'you'],
#  ['gone'],
#  ['Man', 'miss', 'nigahiga'],
#  ['dang',
#   'just',
#   'quit',
#   'youtube',
#   'movie',
#   'for',
#   'mins',
#   'its',
#   'sad',
#   'man'],
#  ['the',
#   'fact',
#   'that',
#   'was',
#   'the',
#   'first',
#   'person',
#   'reach',
#   'million',
#   'subs',
#   'its',
#   'just',
#   'weird'],
#  ['Bro', 'come', 'back', 'please', 'miss', 'you'],
#  ['EVERYONE',
#   'LISTEN',
#   'RYAN',
#   'NOT',
#   'QUITTING',
#   'YOUTUBE',
#   'TOOK',
#   'BREAK',
#   'OFF',
#   'THIS',
#   'ONE',
#   'AND',
#   'CURRENTLY',
#   'UPLOADING',
#   'FREQUENTLY',
#   'HIS',
#   'OTHER',
#   'CHANNEL',
#   'HIGA'],
#  ['Who', 'Still', 'here', 'waiting', 'for', 'Ryan', 'next', 'upload'],
#  ['Where', 'now'],
#  ['For',
#   'those',
#   'who',
#   'are',
#   'only',
#   'this',
#   'channel',
#   'Ryan',
#   'twitch',
#   'has',
#   'been',
#   'there',
#   'for',
#   'year',
#   'check',
#   'him',
#   'out'],
#  ['Dear', 'Ryan', 'can', 'you', 'run', 'high', 'heels'],
#  ['You', 'used', 'the', 'number', 'one', 'most', 'subscribed', 'channel'],
#  ['took',
#   'two',
#   'years',
#   'Japanese',
#   'high',
#   'school',
#   'know',
#   'Chinese',
#   'Classic',
#   'Higa'],
#  ['Dear',
#   'ryn',
#   'create',
#   'fast',
#   'and',
#   'vurius',
#   'movie',
#   'but',
#   'makes',
#   'sense'],
#  ['miss', 'him'],
#  ['Man', 'what', 'would', 'for', 'this', 'channel', 'uploading', 'again'],
#  ['WTF', 'come', 'back', 'and', 'this', 'year', 'old'],
#  ['Dear', 'Ryan', 'make', 'another', 'video'],
#  ['Where', 'are', 'you', 'miss', 'you'],
#  ['and', 'now', 'gone'],
#  ['disappeared', 'when', 'the', 'world', 'needed', 'him', 'the', 'most'],
#  ['know',
#   'Chinese',
#   'because',
#   'took',
#   'Japanese',
#   'class',
#   'Anneyounghaseyo'],
#  ['Why', 'did', 'stop'],
#  ['Dear',
#   'Ryan',
#   'can',
#   'you',
#   'please',
#   'come',
#   'back',
#   'YouTube',
#   'all',
#   'miss',
#   'you'],
#  ['miss', 'its', 'been', 'year'],
#  ['wish', 'did', 'goodbye', 'video'],
#  ['Where', 'Ryan'],
#  ['Pls', 'come', 'back', 'youtube'],
#  ['Hes',
#   'been',
#   'gone',
#   'for',
#   'year',
#   'Some',
#   'guy',
#   'prolly',
#   'tried',
#   'prevent',
#   'covid'],
#  ['Idk', 'guys', 'Would', 'surprised', 'this', 'was'],
#  ['Damn', 'miss', 'the', 'bois'],
#  ['has', 'posted', 'over', 'year'],
#  ['Imagine',
#   'mentioned',
#   'southern',
#   'Asians',
#   'into',
#   'this',
#   'that',
#   'would',
#   'gold'],
#  ['one', 'year', 'later'],
#  ['still', 'waiting', 'for', 'video', 'dude'],
#  ['This',
#   'that',
#   'one',
#   'video',
#   'that',
#   'will',
#   'make',
#   'all',
#   'Americans',
#   'Uneasy'],
#  ['ryan', 'come', 'baaccckkkk'],
#  ['come', 'back', 'please'],
#  ['Miss', 'this'],
#  ['miss', 'Ryan', 'old', 'videos'],
#  ['its', 'been', 'year'],
#  ['near', 'ryan'],
#  ['brother',
#   'when',
#   'will',
#   'upload',
#   'next',
#   'video',
#   'has',
#   'been',
#   'year',
#   'since',
#   'you',
#   'uploaded',
#   'last',
#   'video'],
#  ['Dear', 'Ryan', 'can', 'you', 'make', 'video'],
#  ['Ryan',
#   'you',
#   'haven',
#   'uploaded',
#   'over',
#   'year',
#   'this',
#   'your',
#   'last',
#   'uploaded',
#   'want',
#   'thank',
#   'you',
#   'for',
#   'everything',
#   'you',
#   'done',
#   'for',
#   'YouTube',
#   'Your',
#   'videos',
#   'were',
#   'huge',
#   'part',
#   'childhood',
#   'all',
#   'your',
#   'videos',
#   'were',
#   'amazing'],
#  ['day', 'waiting', 'for', 'idol', 'return'],
#  ['When', 'will', 'you', 'make', 'new', 'video'],
#  ['Haven',
#   'been',
#   'this',
#   'channel',
#   'for',
#   'years',
#   'missed',
#   'what',
#   'Ryan',
#   'can',
#   'bring',
#   'YouTube'],
#  ['What', 'happend', 'him'],
#  ['died'],
#  ['Did', 'die'],
#  ['you', 'see', 'this', 'comment', 'life', 'church'],
#  ['And', 'when', 'the', 'world', 'needed', 'him', 'most', 'vanished'],
#  ['Baby', 'Comeback', 'Thats', 'you', 'nigahiga'],
#  ['you', 'are', 'watching', 'the', 'pure', 'genius', 'youtuber'],
#  ['have', 'not', 'posted'],
#  ['Dear',
#   'Ryan',
#   'can',
#   'you',
#   'make',
#   'sience',
#   'fiction',
#   'movie',
#   'but',
#   'makes',
#   'sense',
#   'and',
#   'actually',
#   'true'],
#  ['need', 'our', 'hero', 'back'],
#  ['Jau', 'det'],
#  ['Det'],
#  ['Year'],
#  ['Still', 'relevant', 'Lmao'],
#  ['was',
#   'movie',
#   'released',
#   'January',
#   'called',
#   'finding',
#   'Ohana',
#   'Maybe',
#   'that',
#   'part',
#   'his',
#   'long',
#   'leave'],
#  ['miss', 'you', 'ryan', 'need', 'you', 'man'],
#  ['ray', 'cancelled'],
#  ['LOL', 'PLEASE', 'THIS', 'FUNNY'],
#  ['Please', 'come', 'back', 'man'],
#  ['man', 'upload', 'again', 'please'],
#  ['sad',
#   'how',
#   'this',
#   'man',
#   'just',
#   'mysteriously',
#   'just',
#   'disappeared',
#   'from',
#   'YouTube'],
#  ['still',
#   'have',
#   'hope',
#   'that',
#   'you',
#   'make',
#   'videos',
#   'that',
#   'why',
#   'are',
#   'subscribed'],
#  ['Please', 'make', 'videos', 'beg'],
#  ['WATCHING', 'THIS', 'NOW', 'STILL', 'FIND', 'EPIC'],
#  ['Ryan', 'where', 'are', 'you'],
#  ['Dear', 'ryan', 'can', 'you', 'post', 'agen'],
#  ['Dear', 'Ryan', 'come', 'back', 'please'],
#  ['miss', 'you', 'Ryan'],
#  ['Where', 'are', 'you', 'need', 'you'],
#  ['Nice',
#   'vedio',
#   'needs',
#   'more',
#   'than',
#   'there',
#   'salary',
#   'financially',
#   'stable',
#   'best',
#   'thing',
#   'with',
#   'your',
#   'money',
#   'invest',
#   'rightly',
#   'money',
#   'left',
#   'for',
#   'saving',
#   'always',
#   'end',
#   'used',
#   'with',
#   'returns',
#   'started',
#   'investing',
#   'Bitcoin',
#   'mid',
#   'November',
#   'with',
#   'the',
#   'help',
#   'well',
#   'professional',
#   'Stephen',
#   'Duncan',
#   'and',
#   'the',
#   'profit',
#   'entirely',
#   'funded',
#   'receipt',
#   'duplex'],
#  ['anyone',
#   'knows',
#   'what',
#   'happened',
#   'nigahiga',
#   'and',
#   'why',
#   'not',
#   'posting',
#   'anymore'],
#  ['Hello', 'are', 'you'],
#  ['Year',
#   'Its',
#   'been',
#   'year',
#   'bro',
#   'where',
#   'are',
#   'you',
#   'miss',
#   'you',
#   'please',
#   'come',
#   'back'],
#  ['Wtf', 'Youtube', 'get', 'these', 'fire', 'recommends'],
#  ['all', 'miss', 'you', 'Ryan'],
#  ['Where', 'did', 'its', 'been', 'year'],
#  ['want', 'collab', 'with', 'you', 'and', 'not', 'famous'],
#  ['please', 'come', 'back', 'ryan'],
#  ['Dear',
#   'ryan',
#   'can',
#   'you',
#   'starp',
#   'posting',
#   'vids',
#   'this',
#   'channel',
#   'again',
#   'miss',
#   'you'],
#  ['Who', 'woulda', 'thought'],
#  ['Dear', 'Ryan', 'Horror', 'Movies', 'but', 'Without', 'slow'],
#  ['Please', 'make', 'new', 'video', 'miss', 'much'],
#  ['Ryan',
#   'higa',
#   'quitting',
#   'youtube',
#   'the',
#   'pandemic',
#   'making',
#   'his',
#   'job',
#   'difficult'],
#  ['come', 'back', 'haven', 'watched', 'min', 'and', 'need', 'you', 'back'],
#  ['Ryan',
#   'just',
#   'want',
#   'say',
#   'thank',
#   'you',
#   'much',
#   'when',
#   'was',
#   'sad',
#   'always',
#   'went',
#   'you',
#   'and',
#   'when',
#   'was',
#   'just',
#   'looking',
#   'laugh',
#   'went',
#   'you',
#   'and',
#   'you',
#   'were',
#   'always',
#   'there',
#   'and',
#   'help',
#   'through',
#   'some',
#   'really',
#   'tough',
#   'times',
#   'and',
#   'when',
#   'pass',
#   'one',
#   'your',
#   'videos',
#   'remember',
#   'all',
#   'the',
#   'times',
#   'laughed',
#   'just',
#   'watching',
#   'you',
#   'and',
#   'wherever',
#   'you',
#   'are',
#   'hope',
#   'you',
#   'doing',
#   'great',
#   'and',
#   'again',
#   'thank',
#   'you',
#   'much'],
#  ['Then', 'when', 'needed', 'him', 'the', 'most', 'disappeared'],
#  ['Why', 'haven', 'you', 'been', 'uploading'],
#  ['year'],
#  ['Dad', 'come', 'back', 'bored'],
#  ['why',
#   'has',
#   'been',
#   'year',
#   'since',
#   'this',
#   'channel',
#   'has',
#   'uploaded',
#   'did',
#   'smite',
#   'them',
#   'for',
#   'putting',
#   'covid',
#   'the',
#   'title',
#   'but',
#   'forgot',
#   'delete',
#   'the',
#   'channel'],
#  ['Bro',
#   'this',
#   'vid',
#   'was',
#   'posited',
#   'year',
#   'ago',
#   'not',
#   'upload',
#   'sooo',
#   'long',
#   'and',
#   'didn',
#   'know',
#   'there',
#   'good',
#   'reason',
#   'sry',
#   'offence',
#   'but',
#   'still',
#   'love',
#   'nigahiga'],
#  ['afraid', 'admit', 'who', 'really', 'does', 'most', 'the', 'attacks'],
#  ['WAS',
#   'YEAR',
#   'AGO',
#   'SINCE',
#   'THE',
#   'LAST',
#   'NIGAHIGA',
#   'VIDEO',
#   'FROM',
#   'RYAN',
#   'Wow',
#   'feel',
#   'want',
#   'force',
#   'Ryan',
#   'what',
#   'does',
#   'wan',
#   'long',
#   'lives',
#   'happily',
#   'really',
#   'enough',
#   'for',
#   'Edit',
#   'you',
#   'know',
#   'Ryan',
#   'got',
#   'burnt',
#   'out',
#   'after',
#   'decade',
#   'Youtube',
#   'Just',
#   'leave',
#   'him',
#   'alone'],
#  ['How', 'long', 'are', 'you', 'gon', 'not', 'post'],
#  ['You', 'haven', 'posted', 'year', 'where', 'you'],
#  ['dear', 'ryan', 'can', 'you', 'make', 'cinematic', 'valorant', 'movie'],
#  ['Dear', 'Ryan', 'please', 'comeback'],
#  ['RYAN', 'BEEN', 'YEAR', 'ARE', 'YOU', 'OKAY'],
#  ['Where',
#   'are',
#   'you',
#   'miss',
#   'you',
#   'and',
#   'hope',
#   'you',
#   'were',
#   'not',
#   'canceled'],
#  ['Please', 'come', 'back'],
#  ['Dear', 'Ryan', 'can', 'you', 'pretend', 'rapper'],
#  ['Come', 'back', 'pls', 'ryan'],
#  ['Came', 'here', 'from', 'disel', 'patches'],
#  ['Why', 'have', 'you', 'posted', 'since', 'last', 'year'],
#  ['pls', 'comebacc'],
#  ['Come', 'back', 'ryan'],
#  ['Come', 'back', 'bro'],
#  ['Dear', 'ryan', 'and', 'gang', 'please', 'post', 'again'],
#  ['where', 'are', 'you', 'come', 'back'],
#  ['Hey', 'Ryan', 'miss', 'you', 'Hope', 'you', 'doing', 'well'],
#  ['Dear', 'Ryan', 'please', 'upload'],
#  ['guys',
#   'some',
#   'you',
#   'know',
#   'ryan',
#   'have',
#   'another',
#   'channel',
#   'named',
#   'HigaTV',
#   'active',
#   'there'],
#  ['You',
#   'should',
#   'make',
#   'follow',
#   'video',
#   'and',
#   'say',
#   'You',
#   'know',
#   'what',
#   'does',
#   'prevent',
#   'coronavirus',
#   'The',
#   'fucking',
#   'vaccine'],
#  ['god', 'been', 'year'],
#  ['Dear', 'Ryan', 'can', 'you', 'try', 'the', 'food', 'biryani'],
#  ['Dear', 'Ryan', 'can', 'you', 'upload'],
#  ['Ryan',
#   'higa',
#   'uploading',
#   'cause',
#   'the',
#   'pandemic',
#   'said',
#   'himself',
#   'twitch'],
#  ['Recent',
#   'update',
#   'The',
#   'Paid',
#   'Actor',
#   'Known',
#   'Ray',
#   'was',
#   'swapping',
#   'for',
#   'the',
#   'real',
#   'perpetrator',
#   'who',
#   'goes',
#   'Tyrese',
#   'Recent',
#   'studies',
#   'shows',
#   'that',
#   'attacks',
#   'Asians',
#   'are',
#   'found',
#   'from',
#   'those',
#   'the',
#   'Hip',
#   'genre',
#   'lol'],
#  ['Its',
#   'been',
#   'year',
#   'since',
#   'his',
#   'last',
#   'video',
#   'when',
#   'will',
#   'make',
#   'new',
#   'one'],
#  ['Thanks', 'Ryan', 'for', 'making', 'amazing', 'content'],
#  ['Dear', 'Ryan', 'Please', 'Comeback'],
#  ['Its', 'all', 'fun', 'and', 'games', 'till', 'made', 'same', 'news'],
#  ['mom', 'met', 'him', 'when', 'was'],
#  ['Guys', 'different', 'channel'],
#  ['Where', 'RyanHiga'],
#  ['Welp', 'guys', 'been', 'year', 'without', 'Ryan', 'this', 'sad'],
#  ['Dear', 'Ryan', 'can', 'you', 'upload', 'new', 'video', 'please'],
#  ['Its',
#   'nice',
#   'see',
#   'that',
#   'ryan',
#   'now',
#   'streams',
#   'over',
#   'twtich',
#   'and',
#   'finding',
#   'new',
#   'hobby'],
#  ['Has', 'quit'],
#  ['Dear', 'Ryan', 'please', 'start', 'making', 'YouTube', 'videos', 'again'],
#  ['DEAR', 'RYAN', 'NEED', 'YOU'],
#  ['People',
#   'are',
#   'being',
#   'irrational',
#   'Clearly',
#   'they',
#   'need',
#   'China',
#   'beat',
#   'people'],
#  ['Its', 'been', 'year'],
#  ['Miss', 'you', 'hope', 'you', 'doing', 'well'],
#  ['Dear', 'Ryan', 'really', 'miss', 'you'],
#  ['worry', 'guys', 'active', 'his', 'second', 'channel', 'HigaTV'],
#  ['This', 'made'],
#  ['please', 'post'],
#  ['Dear', 'Ryan', 'can', 'you', 'come', 'back', 'please'],
#  ['Dear',
#   'Ryan',
#   'can',
#   'you',
#   'make',
#   'skito',
#   'move',
#   'called',
#   'the',
#   'teehee',
#   'virus',
#   'thank',
#   'you'],
#  ['nigahiga', 'are', 'you', 'alive'],
#  ['Dear',
#   'Ryan',
#   'CAN',
#   'PLEASE',
#   'CEEP',
#   'POSTING',
#   'ITS',
#   'BEEN',
#   'YEAR',
#   'NOW'],
#  ['Diesel', 'patches', 'was', 'right', 'this', 'man', 'funny'],
#  ['dont',
#   'want',
#   'your',
#   'legendary',
#   'channel',
#   'die',
#   'like',
#   'filthyfrank',
#   'channel',
#   'dear',
#   'ryan',
#   'pls',
#   'come',
#   'back'],
#  ['please', 'make', 'more', 'content'],
#  ['aRe', 'yOu', 'aLiVe'],
#  ['Oops'],
#  ['hate', 'Asians', 'but', 'from', 'India', 'ever', 'hate'],
#  ['PLEASE',
#   'GOD',
#   'HASN',
#   'UPLOADED',
#   'YEAR',
#   'can',
#   'dying',
#   'out',
#   'that',
#   'would',
#   'crazy',
#   'Right'],
#  ['needs', 'more', 'southern', 'accent'],
#  ['keep',
#   'checking',
#   'back',
#   'see',
#   'these',
#   'guys',
#   'are',
#   'back',
#   'Love',
#   'you',
#   'guys',
#   'and',
#   'your',
#   'creativity',
#   'Please',
#   'please',
#   'please',
#   'bring',
#   'new',
#   'content',
#   'not',
#   'that',
#   'still',
#   'enjoy',
#   'the',
#   'reruns',
#   'but',
#   'please'],
#  ['Niga',
#   'Higa',
#   'has',
#   'not',
#   'really',
#   'uoaded',
#   'any',
#   'video',
#   'for',
#   'Hmmm'],
#  ['Who',
#   'else',
#   'back',
#   'here',
#   'after',
#   'seeing',
#   'Wongfu',
#   'most',
#   'recent',
#   'video'],
#  ['Just', 'like', 'joji', 'this', 'where', 'legends', 'end'],
#  ['Does',
#   'anyone',
#   'else',
#   'see',
#   'how',
#   'this',
#   'almost',
#   'relating',
#   'the',
#   'holocaust',
#   'Hitler',
#   'blamed',
#   'Jewish',
#   'people',
#   'for',
#   'making',
#   'negatively',
#   'affecting',
#   'Germany',
#   'and',
#   'decided',
#   'attack',
#   'them',
#   'and',
#   'here',
#   'America',
#   'racist',
#   'ass',
#   'people',
#   'blame',
#   'asian',
#   'people',
#   'for',
#   'COVID',
#   'and',
#   'decide',
#   'beat',
#   'innocent',
#   'people',
#   'its',
#   'anyone',
#   'think',
#   'that',
#   'the',
#   'asians',
#   'are',
#   'the',
#   'ones',
#   'staying',
#   'safe',
#   'off',
#   'the',
#   'street',
#   'they',
#   'get',
#   'beaten',
#   'while',
#   'these',
#   'people',
#   'beating',
#   'people',
#   'according',
#   'the',
#   'scientist',
#   'are',
#   'going',
#   'out',
#   'making',
#   'physical',
#   'contact',
#   'increasing',
#   'the',
#   'risk',
#   'contracting',
#   'COVID',
#   'which',
#   'pretty',
#   'reasonable'],
#  ['its', 'been', 'year', 'please', 'come', 'back'],
#  ['Ryan', 'still', 'around', 'Twitch', 'Don', 'worry', 'not', 'gone'],
#  ['Damn', 'need', 'new', 'upload'],
#  ['Whose', 'sad', 'that', 'Ryan', 'stopped', 'the', 'channel'],
#  ['coming',
#   'back',
#   'here',
#   'because',
#   'suddenly',
#   'thought',
#   'that',
#   'one',
#   'channel',
#   'that',
#   'actually',
#   'makes',
#   'really',
#   'good',
#   'content'],
#  ['Where', 'are', 'you', 'ryan'],
#  ['Its', 'been', 'year', 'Dear', 'Ryan', 'please', 'come', 'back'],
#  ['been', 'year', 'now', 'and', 'still', 'waiting'],
#  ['dude',
#   'sad',
#   'that',
#   'the',
#   'trending',
#   'videos',
#   'right',
#   'now',
#   'are',
#   'just',
#   'SHORTS',
#   'which',
#   'are',
#   'cringe',
#   'back',
#   'when',
#   'supported',
#   'real',
#   'creators',
#   'like',
#   'this',
#   'guy',
#   'really',
#   'miss',
#   'the',
#   'old',
#   'dude'],
#  ['when',
#   'needed',
#   'him',
#   'the',
#   'most',
#   'never',
#   'cam',
#   'back',
#   'PLEASE',
#   'COMEBACK',
#   'SIR',
#   'PLEASE'],
#  ['Save', 'your', 'tears', 'HigaTV'],
#  ['Dear', 'Ryan', 'Upload', 'Again', 'Please'],
#  ['When', 'you', 'realize', 'Ryan', 'still', 'HigaTV', 'playing', 'SUS'],
#  ['yes', 'agrere'],
#  ['when', 'the', 'day', 'the', 'legend', 'comes', 'back', 'will', 'saved'],
#  ['Ryan', 'quit', 'youtube'],
#  ['its',
#   'been',
#   'year',
#   'Ryan',
#   'what',
#   'happened',
#   'why',
#   'are',
#   'you',
#   'posting',
#   'anymore',
#   'Edit',
#   'just',
#   'found',
#   'higatv'],
#  ['please', 'upload', 'again', 'miss', 'you'],
#  ['sad', 'you', 'left', 'YouTube'],
#  ['dear', 'ryan', 'can', 'you', 'when', 'grow'],
#  ['How', 'comes', 'Ryan', 'doesn', 'make', 'videos', 'anymore'],
#  ['its', 'already', 'been', 'year', 'crying', 'allowed'],
#  ['seriously',
#   'just',
#   'realized',
#   'this',
#   'video',
#   'existence',
#   'after',
#   'your',
#   'mention',
#   'Wong',
#   'production',
#   'youtube',
#   'algorithm',
#   'are',
#   'stupid',
#   'tbh',
#   'Edit',
#   'miss',
#   'your',
#   'video',
#   'ryan'],
#  ['mean', 'ryan', 'not', 'wrong'],
#  ['Dear',
#   'Ryan',
#   'Please',
#   'come',
#   'back',
#   'and',
#   'give',
#   'reason',
#   'not',
#   'lose',
#   'sanity'],
#  ['Youtube', 'are', 'reckt'],
#  ['Dear', 'ryan', 'pls', 'come', 'back'],
#  ['Dude', 'pls', 'come', 'back'],
#  ['dear', 'ryan', 'can', 'you', 'remake', 'how', 'emo'],
#  ['Where', 'nigahiga'],
#  ['Belives'],
#  ['Legends', 'vanish', 'when', 'crisis'],
#  ['This', 'kinda', 'like', 'what', 'happened', 'Japanese', 'Americans'],
#  ['Can', 'alive', 'this', 'already', 'year', 'old', 'time', 'flies'],
#  ['took', 'awhile', 'realize', 'Ray', 'Sisman', 'means', 'racist', 'man'],
#  ['Guys',
#   'can',
#   'acknowledge',
#   'how',
#   'been',
#   'gone',
#   'for',
#   'more',
#   'than',
#   'year',
#   'and',
#   'might',
#   'just',
#   'flat',
#   'out',
#   'dead',
#   'might',
#   'not',
#   'able',
#   'make',
#   'vids',
#   'anymore',
#   'which',
#   'sad',
#   'RYAN',
#   'PLEASE',
#   'COME',
#   'BACK',
#   'MAN',
#   'PLEASE',
#   'COME',
#   'BACK'],
#  ['Last', 'uploaded', 'Year', 'Ago'],
#  ['come', 'back', 'this', 'channel'],
#  ['Japanese',
#   'manga',
#   'with',
#   'straw',
#   'hat',
#   'innocent',
#   'character',
#   'can',
#   'have',
#   'abusive',
#   'immature',
#   'elements',
#   'but',
#   'American',
#   'idiotic',
#   'trend',
#   'phrase',
#   'WHO',
#   'CARES',
#   'America',
#   'can',
#   'become',
#   'ruins'],
#  ['Did', 'just', 'abandoned', 'this', 'channel'],
#  ['Ryan', 'anchorman', 'sound', 'familiar'],
#  ['Theory', 'why', 'Waldo', 'always', 'hiding'],
#  ['Dear', 'Ryan', 'can', 'you', 'dear', 'ryan', 'again'],
#  ['Just',
#   'here',
#   'check',
#   'was',
#   'back',
#   'Returning',
#   'kinda',
#   'disappointed',
#   'again'],
#  ['Goodbye'],
#  ['YEAR', 'AGO'],
#  ['YEAR', 'AND', 'THERE', 'VIDEO', 'PLS'],
#  ['Omg',
#   'saw',
#   'you',
#   'new',
#   'movie',
#   'called',
#   'finding',
#   'ohana',
#   'the',
#   'horse',
#   'rider',
#   'and',
#   'that',
#   'why',
#   'not',
#   'posting',
#   'lol'],
#  ['couldn',
#   'care',
#   'less',
#   'that',
#   'hasn',
#   'uploaded',
#   'over',
#   'year',
#   'Asian',
#   'Ryan',
#   'getting',
#   'continually',
#   'harassed',
#   'online',
#   'racists',
#   'and',
#   'very',
#   'depressed',
#   'about',
#   'What',
#   'Ryan',
#   'Just',
#   'log',
#   'off',
#   'bro',
#   'lol',
#   'Cyberbullying',
#   'first',
#   'world',
#   'problem',
#   'you',
#   'either',
#   'deal',
#   'with',
#   'log',
#   'off',
#   'lol',
#   'Asian',
#   'Hangs',
#   'his'],
#  ['Its',
#   'sad',
#   'how',
#   'many',
#   'original',
#   'youtubers',
#   'don',
#   'record',
#   'now',
#   'and',
#   'they',
#   'stream',
#   'twitch',
#   'something',
#   'remember',
#   'his',
#   'Parkour',
#   'Ninja',
#   'and',
#   'April',
#   'Fools',
#   'stuff'],
#  ['Come', 'Back'],
#  ['the', 'only', 'one', 'who', 'miss', 'this', 'dude'],
#  ['Wish',
#   'could',
#   'turn',
#   'back',
#   'time',
#   'the',
#   'good',
#   'old',
#   'days',
#   'Where',
#   'pewdipie',
#   'had',
#   'white',
#   'beard',
#   'Nigahiga',
#   'released',
#   'the',
#   'ifhone',
#   'Dantdm',
#   'showed',
#   'the',
#   'Labrotary',
#   'Markiplier',
#   'did',
#   'nights',
#   'Freddy',
#   'But',
#   'now',
#   'are',
#   'lonely'],
#  ['Come', 'back', 'Ryan', 'This', 'Shithole', 'needs', 'some', 'gold'],
#  ['already', 'been', 'year'],
#  ['Ryan', 'posting', 'schedule', 'even', 'worse', 'than', 'vsauce'],
#  ['would',
#   'see',
#   'this',
#   'did',
#   'search',
#   'him',
#   'wtf',
#   'youtube',
#   'and',
#   'youtube',
#   'algorithm'],
#  ['felt',
#   'over',
#   'worked',
#   'and',
#   'stopped',
#   'creating',
#   'YouTube',
#   'for',
#   'fun',
#   'The',
#   'enjoyment',
#   'left',
#   'and',
#   'said',
#   'wanted',
#   'other',
#   'things',
#   'and',
#   'focus',
#   'his',
#   'own',
#   'happiness',
#   'the',
#   'videos',
#   'got',
#   'less',
#   'frequent',
#   'when',
#   'got',
#   'hard',
#   'for',
#   'him',
#   'and',
#   'eventually',
#   'stopped',
#   'watched',
#   'his',
#   'videos',
#   'from',
#   'years',
#   'ago',
#   'but',
#   'instead',
#   'being',
#   'sad',
#   'over',
#   'just',
#   'happy',
#   'was',
#   'creative',
#   'for',
#   'everyone',
#   'hope',
#   'really',
#   'found',
#   'joy',
#   'his',
#   'life',
#   'these',
#   'days'],
#  ['Wish', 'they', 'would', 'upload'],
#  ['How',
#   'only',
#   'now',
#   'seeing',
#   'this',
#   'video',
#   'after',
#   'year',
#   'don',
#   'recall',
#   'seeing',
#   'this',
#   'sub',
#   'box'],
#  ['did', 'quit', 'Hopefully', 'And', 'beat', 'Asian'],
#  ['need',
#   'Ryan',
#   'Higa',
#   'and',
#   'KevJumba',
#   'back',
#   'life',
#   'Them',
#   'being',
#   'gone',
#   'honestly',
#   'makes',
#   'cry',
#   'They',
#   'meant',
#   'much',
#   'growing',
#   'refuse',
#   'unsubscribe',
#   'either',
#   'them',
#   'Instagram',
#   'YouTube',
#   'etc'],
#  ['This', 'the', 'vid', 'from', 'year', 'ago', 'Where', 'are', 'you'],
#  ['WHERE', 'ARE', 'YOU'],
#  ['Can',
#   'someone',
#   'please',
#   'explain',
#   'why',
#   'this',
#   'legend',
#   'stopped',
#   'making',
#   'videos',
#   'Thanks'],
#  ['this', 'guy', 'ever', 'comes', 'back', 'trending', 'for', 'like', 'week'],
#  ['Where', 'are', 'new', 'videossssss'],
#  ['year', 'and', 'update'],
#  ['remember',
#   'watching',
#   'this',
#   'when',
#   'came',
#   'out',
#   'and',
#   'being',
#   'like',
#   'bet',
#   'back',
#   'skits',
#   'can',
#   'wait',
#   'for',
#   'what',
#   'posts',
#   'next',
#   'then',
#   'year',
#   'goes',
#   'watched',
#   'him',
#   'since',
#   'how',
#   'ninja',
#   'miss',
#   'these',
# ...
#   'tactics',
#   'are',
#   'recommended',
#   'confused'],
#  ['Not',
#   'gon',
#   'lie',
#   'was',
#   'searching',
#   'the',
#   'comments',
#   'for',
#   'hate',
#   'comments'],
#  ['have', 'marry', 'our', 'own', 'cousin', 'now', 'hahahhaa', 'lol'],
#  ['PLS', 'COMEBACKKKKKKK', 'ALWAYS', 'MAKE', 'LAUGHHHHHH'],
#  ['Hey', 'how', 'are', 'you', 'ryan'],
#  ['This',
#   'video',
#   'hilarious',
#   'and',
#   'clever',
#   'wish',
#   'this',
#   'issue',
#   'was',
#   'covered',
#   'more',
#   'the',
#   'media',
#   'tho',
#   'feels',
#   'like',
#   'keeps',
#   'getting',
#   'brushed',
#   'off',
#   'even',
#   'now'],
#  ['hahahahah'],
#  ['This', 'was', 'the', 'last', 'video'],
#  ['Goodbye',
#   'one',
#   'the',
#   'youtubers',
#   'since',
#   'the',
#   'beginning',
#   'Its',
#   'been',
#   'fun',
#   'journey',
#   'together',
#   'Ryan',
#   'hope',
#   'you',
#   'find',
#   'your',
#   'passion',
#   'elsewhere'],
#  ['Ryan',
#   'still',
#   'got',
#   'his',
#   'guard',
#   'just',
#   'need',
#   'idea',
#   'pay',
#   'rent'],
#  ['The',
#   'same',
#   'people',
#   'beating',
#   'Asian',
#   'people',
#   'are',
#   'the',
#   'same',
#   'people',
#   'who',
#   'are',
#   'unwilling',
#   'put',
#   'mask',
#   'and',
#   'trying',
#   'prevent',
#   'the',
#   'virus'],
#  ['are',
#   'number',
#   'Are',
#   'Number',
#   'Are',
#   'Number',
#   'ARE',
#   'Number',
#   'ARE',
#   'NUMBER'],
#  ['amazing',
#   'how',
#   'this',
#   'the',
#   'topic',
#   'that',
#   'will',
#   'present',
#   'this',
#   'friday',
#   'class',
#   'thanks',
#   'ryan'],
#  ['Ray', 'Sisman', 'more', 'like', 'Racist', 'man'],
#  ['forgot', 'mention', 'whos', 'actually', 'committing', 'these', 'crimes'],
#  ['America', 'nambawan', 'covid', 'cases', 'and', 'death'],
#  ['PREDICTIVE', 'PROGRAMMING'],
#  ['RAY', 'CISMAN', 'Now', 'that', 'was', 'clever'],
#  ['really',
#   'get',
#   'You',
#   'are',
#   'afraid',
#   'virus',
#   'you',
#   'get',
#   'close',
#   'contact',
#   'with',
#   'someone',
#   'you',
#   'believe',
#   'infected',
#   'because',
#   'they',
#   'are',
#   'infected',
#   'Make',
#   'make',
#   'sense'],
#  ['Please', 'comeback'],
#  ['Well',
#   'some',
#   'may',
#   'still',
#   'thinks',
#   'that',
#   'all',
#   'latinos',
#   'are',
#   'mexican',
#   'too',
#   'You',
#   'realize',
#   'that',
#   'education',
#   'system',
#   'should',
#   'teach',
#   'geography',
#   'they'],
#  ['yeah',
#   'when',
#   'people',
#   'racist',
#   'black',
#   'people',
#   'its',
#   'all',
#   'that',
#   'but',
#   'when',
#   'its',
#   'asian',
#   'its',
#   'like'],
#  ['First',
#   'all',
#   'who',
#   'unsubscribed',
#   'from',
#   'Nigahiga',
#   'Second',
#   'all',
#   'how',
#   'just',
#   'seeing',
#   'this'],
#  ['Asia', 'literally', 'has', 'countries', 'yea'],
#  ['This',
#   'good',
#   'but',
#   'racists',
#   'aren',
#   'smart',
#   'enough',
#   'understand',
#   'even',
#   'secs',
#   'this',
#   'video'],
#  ['can',
#   'not',
#   'blame',
#   'every',
#   'foreigners',
#   'every',
#   'countries',
#   'Most',
#   'them',
#   'sacrifices',
#   'themselves',
#   'there',
#   'families',
#   'find',
#   'money',
#   'amd',
#   'give',
#   'support',
#   'just',
#   'waiting',
#   'something',
#   'big',
#   'happen',
#   'between',
#   'this',
#   'countries',
#   'Excited',
#   'see',
#   'what',
#   'the',
#   'news',
#   'who',
#   'wins',
#   'and',
#   'who',
#   'lost',
#   'Its',
#   'better',
#   'make',
#   'flattened',
#   'the',
#   'whole',
#   'nation',
#   'but',
#   'let',
#   'this',
#   'people',
#   'alive',
#   'with',
#   'trees',
#   'plants',
#   'animals',
#   'water',
#   'fish',
#   'only',
#   'berries'],
#  ['covid', 'came', 'from', 'america'],
#  ['this', 'broadcast', 'should', 'everywhere'],
#  ['Plzzz', 'upload', 'another', 'vid', 'Ryan', 'need', 'tooooooooooooooo'],
#  ['said',
#   'teehee',
#   'then',
#   'remembered',
#   'this',
#   'guy',
#   'and',
#   'how',
#   'haven',
#   'seen',
#   'him',
#   'long',
#   'recommend'],
#  ['thought',
#   'would',
#   'say',
#   'Stay',
#   'safe',
#   'stay',
#   'home',
#   'and',
#   'cook',
#   'rice'],
#  ['Well',
#   'the',
#   'Chinese',
#   'ccp',
#   'virus',
#   'but',
#   'please',
#   'beat',
#   'non',
#   'ccp',
#   'Chinese',
#   'people',
#   'please',
#   'Thats',
#   'just',
#   'stoopid'],
#  ['Lmao'],
#  ['Remember',
#   'back',
#   'the',
#   'day',
#   'when',
#   'the',
#   'white',
#   'people',
#   'brought',
#   'their',
#   'own',
#   'covid',
#   'america',
#   'killing',
#   'lots',
#   'native',
#   'americans',
#   'Yeah',
#   'but',
#   'that',
#   'time',
#   'the',
#   'sickness',
#   'was',
#   'called',
#   'smallpox',
#   'and',
#   'was',
#   'worst'],
#  ['You',
#   'know',
#   'what',
#   'more',
#   'hilarious',
#   'This',
#   'video',
#   'got',
#   'Covid',
#   'nottification',
#   'right',
#   'below'],
#  ['just',
#   'came',
#   'across',
#   'news',
#   'that',
#   'Thai',
#   'person',
#   'was',
#   'harmed',
#   'and',
#   'her',
#   'cat',
#   'died',
#   'heart',
#   'attack',
#   'via',
#   'years',
#   'old',
#   'boy',
#   'Then',
#   'his',
#   'parents',
#   'came',
#   'hurt',
#   'the',
#   'owner',
#   'and',
#   'her',
#   'birds',
#   'dog',
#   'The',
#   'Thai',
#   'woman',
#   'has',
#   'evidences',
#   'yet',
#   'policemen',
#   'ignored',
#   'Then',
#   'YouTube',
#   'recommended',
#   'this',
#   'Thanks'],
#  ['wish', 'someone', 'had', 'said', 'something', 'earlier'],
#  ['Wuhan',
#   'Virus',
#   'Chinese',
#   'Govt',
#   'the',
#   'problem',
#   'not',
#   'the',
#   'Chinese',
#   'people'],
#  ['missed', 'seeing', 'you', 'ahhhhhhhh', 'Please', 'make', 'more', 'videos'],
#  ['Genius'],
#  ['Why', 'did', 'you', 'quit'],
#  ['Imagine',
#   'someone',
#   'putting',
#   'mask',
#   'and',
#   'washing',
#   'hands',
#   'and',
#   'proceeding',
#   'beat',
#   'the',
#   'shit',
#   'out',
#   'you',
#   'What',
#   'are',
#   'you',
#   'gon',
#   'Say',
#   'thank',
#   'you'],
#  ['Yall',
#   'look',
#   'exactly',
#   'the',
#   'same',
#   'Yall',
#   'are',
#   'the',
#   'same',
#   'person',
#   'Ray',
#   'almost',
#   'caused',
#   'glitch',
#   'the',
#   'matrix'],
#  ['very',
#   'mad',
#   'when',
#   'they',
#   'say',
#   'muslim',
#   'are',
#   'terrorists',
#   'cuz',
#   'cuz',
#   'they',
#   'said',
#   'white',
#   'people',
#   'cover',
#   'all',
#   'they',
#   'body',
#   'and',
#   'attach',
#   'the',
#   'White',
#   'House',
#   'Are',
#   'majority',
#   'American',
#   'white',
#   'bet',
#   'the',
#   'one',
#   'who',
#   'attacked',
#   'White',
#   'House',
#   'are',
#   'American',
#   'people',
#   'not',
#   'Muslim'],
#  ['confuse',
#   'cuz',
#   'are',
#   'real',
#   'American',
#   'people',
#   'are',
#   'red',
#   'Indian',
#   'Most',
#   'American',
#   'said',
#   'foreigner',
#   'back',
#   'their',
#   'country',
#   'and',
#   'those',
#   'who',
#   'said',
#   'are',
#   'sure',
#   'their',
#   'ancestors',
#   'red',
#   'Indian',
#   'bet',
#   'not'],
#  ['People',
#   'hate',
#   'crime',
#   'but',
#   'America',
#   'like',
#   'judge',
#   'first',
#   'most',
#   'them',
#   'love',
#   'beating',
#   'foreigner'],
#  ['Dear', 'Ryan', 'can', 'you', 'make', 'nother', 'skitzo'],
#  ['anything',
#   'else',
#   'having',
#   'physical',
#   'contact',
#   'being',
#   'melee',
#   'range',
#   'other',
#   'players',
#   'will',
#   'make',
#   'you',
#   'more',
#   'vulnerable',
#   'the',
#   'coronavirus'],
#  ['LOUDER',
#   'FOR',
#   'THE',
#   'PEOPLE',
#   'THE',
#   'BACK',
#   'all',
#   'honesty',
#   'pulled',
#   'this',
#   'off',
#   'well'],
#  ['THOUGHT', 'THIS', 'WAS', 'NEWS', 'CHANNEL'],
#  ['Stop', 'hurting', 'asians'],
#  ['should', 'make', 'another', 'why', 'havent', 'posted', 'Vid'],
#  ['are',
#   'coming',
#   'year',
#   'without',
#   'nigahiga',
#   'youtube',
#   'hes',
#   'basically',
#   'all',
#   'twitch',
#   'now'],
#  ['and', 'the', 'hate', 'crimes', 'continues', 'grow'],
#  ['please',
#   'upload',
#   'something',
#   'even',
#   'crap',
#   'its',
#   'better',
#   'than',
#   'most',
#   'almost',
#   'all',
#   'other',
#   'youtubers'],
#  ['thought', 'this', 'was', 'real', 'news', 'for', 'sec'],
#  ['Ray', 'sisman'],
#  ['are',
#   'literally',
#   'the',
#   'same',
#   'place',
#   'year',
#   'later',
#   'hate',
#   'crimes',
#   'towards',
#   'asians',
#   'are',
#   'getting',
#   'even',
#   'worse',
#   'and',
#   'now',
#   'its',
#   'towards',
#   'old',
#   'people',
#   'nigahiga',
#   'has',
#   'always',
#   'been',
#   'ahead',
#   'his',
#   'time'],
#  ['would', 'cool', 'you', 'made', 'Friday', 'night', 'funkin', 'parity'],
#  ['why',
#   'supposed',
#   'luxury',
#   'brands',
#   'such',
#   'Omega',
#   'and',
#   'Rolex',
#   'let',
#   'medical',
#   'doctor',
#   'whatever',
#   'customers',
#   'abuse',
#   'children',
#   'Well',
#   'Chanel',
#   'has',
#   'nel',
#   'knell',
#   'under',
#   'late',
#   'German',
#   'buyers',
#   'they',
#   'might',
#   'not',
#   'care'],
#  ['CMON', 'COME', 'BACK', 'YOUTUBE'],
#  ['took',
#   'years',
#   'Japanese',
#   'high',
#   'school',
#   'speak',
#   'Chinese',
#   'Proceeds',
#   'say',
#   'hello',
#   'Korean'],
#  ['Way', 'slap', 'hate', 'stupid', 'USA', 'face'],
#  ['When',
#   'the',
#   'news',
#   'about',
#   'Corn',
#   'con',
#   'being',
#   'eaten',
#   'alive',
#   'campus',
#   'animals',
#   'and',
#   'else',
#   'after',
#   'the',
#   'con',
#   'plagiarized',
#   'Youtube',
#   'comments',
#   'into',
#   'scholarly',
#   'papers'],
#  ['actually',
#   'thought',
#   'was',
#   'real',
#   'only',
#   'the',
#   'first',
#   'part',
#   'until',
#   'saw',
#   'him',
#   'acting',
#   'another',
#   'person'],
#  ['Damn', 'really'],
#  ['can', 'you', 'make', 'the', 'biggest', 'pranks', 'your', 'friends'],
#  ['bruh', 'moment'],
#  ['Its',
#   'sad',
#   'how',
#   'americans',
#   'are',
#   'struggling',
#   'STILL',
#   'with',
#   'coronavirus',
#   'while',
#   'here',
#   'asia',
#   'are',
#   'about',
#   'back',
#   'into',
#   'our',
#   'normal',
#   'lived',
#   'because',
#   'FOLLOW',
#   'PROTOCOLS',
#   'hate',
#   'but',
#   'its',
#   'the',
#   'truth',
#   'dont',
#   'deny'],
#  ['Love', 'this'],
#  ['This',
#   'was',
#   'made',
#   'months',
#   'ago',
#   'and',
#   'didn',
#   'know',
#   'how',
#   'bad',
#   'could',
#   'get',
#   'Really',
#   'depressing'],
#  ['Omg', 'Nigahiga', 'still', 'active', 'Youtube', 'Shit', 'life', 'good'],
#  ['been', 'ten', 'years', 'why', 'are', 'still', 'here', 'Just', 'suffer'],
#  ['not',
#   'that',
#   'left',
#   'that',
#   'really',
#   'didn',
#   'get',
#   'here',
#   'him',
#   'say',
#   'goodbye'],
#  ['ryan',
#   'netflix',
#   'movie',
#   'called',
#   'finding',
#   'ohana',
#   'and',
#   'plays',
#   'the',
#   'security',
#   'guard',
#   'ryan',
#   'the',
#   'movie'],
#  ['this', 'man', 'comedic', 'and', 'satire', 'prowess', 'underrated'],
#  ['Dear',
#   'Ryan',
#   'can',
#   'you',
#   'make',
#   'video',
#   'about',
#   'the',
#   'different',
#   'types',
#   'laughs'],
#  ['you',
#   'guys',
#   'are',
#   'pure',
#   'genius',
#   'and',
#   'downright',
#   'hilarious',
#   'basically',
#   'every',
#   'point',
#   'you',
#   'made',
#   'echoed',
#   'thoughts',
#   'sharing',
#   'this',
#   'skit',
#   'with',
#   'friends',
#   'black',
#   'lives',
#   'matter',
#   'and',
#   'asian',
#   'lives',
#   'matter',
#   'too',
#   'keep',
#   'strong',
#   'stay',
#   'safe',
#   'GOD',
#   'BLESS'],
#  ['Dear', 'Ryan', 'can', 'you', 'upload', 'again'],
#  ['Angry', 'weaken', 'your', 'immunity', 'catch', 'Covid', 'fast'],
#  ['Dear', 'Ryan', 'can', 'you', 'how', 'emo'],
#  ['Really',
#   'loved',
#   'the',
#   'sarcastic',
#   'feel',
#   'this',
#   'made',
#   'giggle',
#   'But',
#   'also',
#   'hope',
#   'that',
#   'those',
#   'who',
#   'are',
#   'were',
#   'being',
#   'hateful',
#   'would',
#   'look',
#   'this',
#   'and',
#   'wow',
#   'dumb',
#   'ass'],
#  ['Hate', 'crimes', 'are', 'still', 'thing', 'Yikes'],
#  ['Why', 'aren', 'you', 'posting'],
#  ['took',
#   'like',
#   'minutes',
#   'get',
#   'that',
#   'ray',
#   'sisman',
#   'supposed',
#   'sound',
#   'like',
#   'racist',
#   'man'],
#  ['LOL', 'THIS', 'SHOULD', 'COMMON', 'LOGIC', 'BUT', 'APPARENTLY', 'NOT'],
#  ['Just', 'wondering', 'when', 'will', 'you', 'upload', 'new', 'vids'],
#  ['love', 'this', 'video', 'and', 'this', 'man', 'beyond', 'words'],
#  ['Hahaha', 'Fax', 'People', 'stupid'],
#  ['months', 'ago'],
#  ['YOU',
#   'ARE',
#   'GOOD',
#   'AND',
#   'LOVELY',
#   'HOLY',
#   'CRAP',
#   'NEED',
#   'MORE',
#   'YOU'],
#  ['have',
#   'say',
#   'this',
#   'have',
#   'seen',
#   'black',
#   'people',
#   'hashing',
#   'out',
#   'hate',
#   'crimes',
#   'against',
#   'Asians',
#   'quite',
#   'bit',
#   'From',
#   'personal',
#   'experience',
#   'being',
#   'South',
#   'east',
#   'Asian',
#   'was',
#   'also',
#   'attacked',
#   'some',
#   'black',
#   'teens',
#   'park',
#   'while',
#   'was',
#   'walking',
#   'minding',
#   'own',
#   'business',
#   'they',
#   'said',
#   'you',
#   'belong',
#   'here',
#   'and',
#   'carried',
#   'for',
#   'quite',
#   'while',
#   'threatening',
#   'physical',
#   'harm',
#   'throwing',
#   'fire',
#   'crackers',
#   'was',
#   'bad',
#   'had',
#   'make',
#   'police',
#   'report',
#   'really',
#   'not',
#   'understand',
#   'this',
#   'mindset',
#   'you',
#   'have',
#   'felt',
#   'oppressed',
#   'and',
#   'enslaved',
#   'for',
#   'years',
#   'how',
#   'does',
#   'that',
#   'justify',
#   'your',
#   'going',
#   'out',
#   'and',
#   'attacking',
#   'others',
#   'races',
#   'Everyone',
#   'supported',
#   'the',
#   'BLM',
#   'movement',
#   'and',
#   'this',
#   'the',
#   'payback',
#   'The',
#   'people',
#   'whom',
#   'everyone',
#   'felt',
#   'bad',
#   'for',
#   'years',
#   'turn',
#   'out',
#   'quite',
#   'racist',
#   'themselves',
#   'Who',
#   'say',
#   'what',
#   'they',
#   'would',
#   'have',
#   'done',
#   'they',
#   'were',
#   'the',
#   'foremost',
#   'race',
#   'the',
#   'world',
#   'saying',
#   'this',
#   'knowing',
#   'have',
#   'many',
#   'half',
#   'asian',
#   'caribbean',
#   'friends',
#   'and',
#   'some',
#   'Nigerian',
#   'friends',
#   'well',
#   'and',
#   'they',
#   'are',
#   'very',
#   'nice',
#   'people',
#   'but',
#   'some',
#   'who',
#   'migrated',
#   'long',
#   'back',
#   'western',
#   'countries',
#   'are',
#   'uneducated',
#   'and',
#   'hateful',
#   'Its',
#   'quite',
#   'shock',
#   'did',
#   'not',
#   'expect',
#   'such',
#   'thing',
#   'because',
#   'had',
#   'good',
#   'experiences',
#   'with',
#   'newer',
#   'black',
#   'immigrants',
#   'who',
#   'were',
#   'nice',
#   'spiritual',
#   'and',
#   'thoughtful',
#   'that',
#   'was',
#   'shocked',
#   'when',
#   'met',
#   'the',
#   'other',
#   'type'],
#  ['RYAN',
#   'PLEASE',
#   'COME',
#   'BACKKK',
#   'STILL',
#   'HERE',
#   'WAITING',
#   'FOR',
#   'YOU',
#   'LOVE',
#   'YOU',
#   'RYANNNN'],
#  ['The',
#   'type',
#   'people',
#   'assaults',
#   'asians',
#   'more',
#   'than',
#   'Type',
#   'people',
#   'and',
#   'media',
#   'always',
#   'blame',
#   'the',
#   'Type',
#   'people'],
#  ['Almost', 'year', 'now'],
#  ['respect', 'This', 'damn', 'accurate'],
#  ['Nigahiga', 'plslslslslsslsllsls', 'come', 'back', 'pls'],
#  ['Still', 'accurate', 'now'],
#  ['Beuh',
#   'rqcist',
#   'people',
#   'always',
#   'saying',
#   'xaysed',
#   'but',
#   'when',
#   'were',
#   'asked',
#   'follow',
#   'the',
#   'rules',
#   'new',
#   'normal',
#   'people',
#   'breakin',
#   'the',
#   'rules',
#   'wth'],
#  ['man',
#   'almost',
#   'been',
#   'entire',
#   'year',
#   'since',
#   'your',
#   'last',
#   'upload',
#   'miss',
#   'you',
#   'ryan'],
#  ['don', 'say'],
#  ['fck', 'hahahaha'],
#  ['Aged', 'like', 'fine', 'wine'],
#  ['Imagine',
#   'being',
#   'Canadian',
#   'and',
#   'people',
#   'just',
#   'start',
#   'hating',
#   'you',
#   'for',
#   'having',
#   'those',
#   'eyes'],
#  ['this',
#   'channel',
#   'dead',
#   'ryan',
#   'Please',
#   'make',
#   'bit',
#   'content',
#   'here',
#   'from',
#   'time',
#   'time',
#   'Monthly',
#   'perhaps'],
#  ['months', 'still', 'uploads'],
#  ['Ryan',
#   'would',
#   'actually',
#   'pretty',
#   'good',
#   'news',
#   'reporter',
#   'got',
#   'the',
#   'voice',
#   'lol'],
#  ['The', 'Hazardous', 'States', 'America'],
#  ['When', 'need', 'say', 'most', 'went', 'away'],
#  ['This',
#   'obscene',
#   'Those',
#   'who',
#   'act',
#   'that',
#   'way',
#   'toward',
#   'other',
#   'human',
#   'beings',
#   'are',
#   'actually',
#   'far',
#   'more',
#   'likely',
#   'get',
#   'because',
#   'their',
#   'shrunken',
#   'telomeres',
#   'increase',
#   'cortisol',
#   'overwhelming',
#   'immunity',
#   'and',
#   'how',
#   'everything',
#   'connected',
#   'the',
#   'human',
#   'body',
#   'Communist',
#   'opportunists',
#   'who',
#   'want',
#   'excuse',
#   'unleash',
#   'their',
#   'hatred',
#   'humanity',
#   'against',
#   'humanity',
#   'did',
#   'They',
#   'create',
#   'the',
#   'problems',
#   'society',
#   'order',
#   'make',
#   'themselves',
#   'appear',
#   'more',
#   'like',
#   'the',
#   'solution',
#   'Patriots',
#   'which',
#   'include',
#   'many',
#   'Asian',
#   'Americans',
#   'well',
#   'every',
#   'other',
#   'race',
#   'actually',
#   'working',
#   'together',
#   'treat',
#   'the',
#   'concerns',
#   'the',
#   'nation',
#   'against',
#   'threats',
#   'both',
#   'foreign',
#   'and',
#   'domestic',
#   'whole',
#   'did',
#   'and',
#   'would',
#   'that'],
#  ['but',
#   'that',
#   'where',
#   'you',
#   'fucked',
#   'You',
#   'see',
#   'Ryan',
#   'RPGs',
#   'when',
#   'you',
#   'beat',
#   'people',
#   'they',
#   'drop',
#   'item',
#   'want',
#   'that',
#   'cure',
#   'Cracks',
#   'knuckles'],
#  ['bravo'],
#  ['Its',
#   'not',
#   'right',
#   'they',
#   'are',
#   'human',
#   'too',
#   'its',
#   'not',
#   'their',
#   'fault'],
#  ['sense', 'lot', 'realism', 'from', 'that', 'speech'],
#  ['really', 'like'],
#  ...]
